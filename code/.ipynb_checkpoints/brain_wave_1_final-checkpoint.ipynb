# 25                           Credit card or prepaid card
# 26                               Bank account or service
# 27                                      Credit reporting
# 28     Credit reporting, credit repair services, or o...
# 29                                       Debt collection
# ...                                                  ...
# 43236                            Bank account or service
# 43237                                           Mortgage
# 43238                                      Consumer Loan
# 43239                                        Credit card
# 43240                                           Mortgage
# 43241                                   Credit reporting
# 43242                                   Credit reporting
# 43243                                           Mortgage
# 43244                                           Mortgage
# 43245                                           Mortgage
# 43246                                    Debt collection
# 43247                            Bank account or service
# 43248                                   Credit reporting
# 43249                                    Debt collection
# 43250                                           Mortgage
# 43251                                        Credit card
# 43252                                    Debt collection
# 43253                                    Debt collection
# 43254                                    Debt collection
# 43255                                           Mortgage
# 43256                                           Mortgage
# 43257                                        Credit card
# 43258                                    Debt collection
# 43259                                           Mortgage
# 43260  Credit reporting, credit repair services, or o...
# 43261  Credit reporting, credit repair services, or o...
# 43262                                    Debt collection
# 43263                                           Mortgage
# 43264                                           Mortgage
# 43265                                    Debt collection
#
#                                         Complaint-reason  \
# 0               Loan servicing, payments, escrow account
# 1                 Incorrect information on credit report
# 2                              Using a debit or ATM card
# 3                  Cont'd attempts collect debt not owed
# 4                                         Payoff process
# 5               Loan modification,collection,foreclosure
# 6                 Incorrect information on credit report
# 7                  Problems caused by my funds being low
# 8                  Cont'd attempts collect debt not owed
# 9                 Incorrect information on credit report
# 10              Loan servicing, payments, escrow account
# 11              Credit card protection / Debt protection
# 12                Incorrect information on credit report
# 13                Incorrect information on credit report
# 14                            Managing the loan or lease
# 15                          Problem when making payments
# 16                  Incorrect information on your report
# 17                    False statements or representation
# 18                       Disclosure verification of debt
# 19                 Cont'd attempts collect debt not owed
# 20                 Customer service / Customer relations
# 21                           Improper use of your report
# 22              Loan servicing, payments, escrow account
# 23                            Managing the loan or lease
# 24                Incorrect information on credit report
# 25                          Problem when making payments
# 26                              Deposits and withdrawals
# 27                Incorrect information on credit report
# 28                  Incorrect information on your report
# 29                                 Communication tactics
# ...                                                  ...
# 43236              Problems caused by my funds being low
# 43237           Application, originator, mortgage broker
# 43238           Charged fees or interest I didn't expect
# 43239                               APR or interest rate
# 43240           Loan servicing, payments, escrow account
# 43241             Incorrect information on credit report
# 43242             Incorrect information on credit report
# 43243           Loan modification,collection,foreclosure
# 43244           Application, originator, mortgage broker
# 43245           Loan servicing, payments, escrow account
# 43246              Cont'd attempts collect debt not owed
# 43247                           Deposits and withdrawals
# 43248             Incorrect information on credit report
# 43249                              Communication tactics
# 43250           Loan servicing, payments, escrow account
# 43251                                 Delinquent account
# 43252              Cont'd attempts collect debt not owed
# 43253               Taking/threatening an illegal action
# 43254                Improper contact or sharing of info
# 43255           Loan modification,collection,foreclosure
# 43256           Loan servicing, payments, escrow account
# 43257                                  Billing statement
# 43258  Took or threatened to take negative or legal a...
# 43259           Loan modification,collection,foreclosure
# 43260               Incorrect information on your report
# 43261                        Improper use of your report
# 43262              Cont'd attempts collect debt not owed
# 43263           Loan modification,collection,foreclosure
# 43264                     Trouble during payment process
# 43265                  Attempts to collect debt not owed
#
#                                         Company-response Date-sent-to-company  \
# 0                                                    NaN           11/11/2015
# 1       Company chooses not to provide a public response             7/7/2015
# 2                                                    NaN             5/7/2015
# 3      Company believes it acted appropriately as aut...           11/12/2016
# 4      Company has responded to the consumer and the ...            9/29/2016
# 5                                                    NaN             8/3/2016
# 6                                                    NaN            3/26/2017
# 7      Company has responded to the consumer and the ...           10/15/2016
# 8                                                    NaN            1/18/2016
# 9       Company chooses not to provide a public response            8/17/2015
# 10                                                   NaN            1/15/2016
# 11                                                   NaN             3/5/2016
# 12     Company has responded to the consumer and the ...            1/29/2016
# 13      Company chooses not to provide a public response            9/24/2015
# 14                                                   NaN           12/28/2016
# 15     Company has responded to the consumer and the ...            8/17/2017
# 16     Company has responded to the consumer and the ...             5/2/2017
# 17                                                   NaN            9/29/2016
# 18     Company disputes the facts presented in the co...             3/2/2017
# 19                                                   NaN             9/7/2016
# 20                                                   NaN            2/18/2016
# 21                                                   NaN             9/8/2017
# 22                                                   NaN            4/28/2016
# 23     Company believes complaint is the result of an...            5/19/2016
# 24                                                   NaN            3/10/2017
# 25     Company believes it acted appropriately as aut...            6/22/2017
# 26     Company believes it acted appropriately as aut...            1/31/2016
# 27                                                   NaN            2/18/2016
# 28     Company has responded to the consumer and the ...            7/13/2017
# 29                                                   NaN             6/4/2015
# ...                                                  ...                  ...
# 43236  Company has responded to the consumer and the ...           11/18/2016
# 43237  Company has responded to the consumer and the ...             9/9/2016
# 43238  Company believes it acted appropriately as aut...            7/31/2015
# 43239  Company has responded to the consumer and the ...            1/31/2017
# 43240                                                NaN            1/27/2017
# 43241                                                NaN            8/11/2016
# 43242                                                NaN             7/2/2016
# 43243                                                NaN            4/28/2015
# 43244                                                NaN            1/12/2016
# 43245                                                NaN             9/4/2015
# 43246                                                NaN            7/19/2015
# 43247                                                NaN            5/28/2016
# 43248                                                NaN           12/27/2016
# 43249                                                NaN            7/23/2015
# 43250                                                NaN            5/20/2016
# 43251  Company has responded to the consumer and the ...             3/2/2016
# 43252  Company believes it acted appropriately as aut...            4/21/2017
# 43253                                                NaN            9/21/2015
# 43254  Company believes the complaint is the result o...            12/4/2016
# 43255  Company believes complaint is the result of an...             6/5/2016
# 43256                                                NaN            9/28/2015
# 43257                                                NaN             5/1/2015
# 43258                                                NaN             5/9/2017
# 43259  Company has responded to the consumer and the ...           11/23/2016
# 43260  Company has responded to the consumer and the ...            5/10/2017
# 43261                                                NaN            7/28/2017
# 43262                                                NaN            1/23/2017
# 43263                                                NaN            3/13/2017
# 43264  Company believes complaint is the result of an...            7/15/2017
# 43265  Company believes it acted appropriately as aut...             6/8/2017
#
#                       Complaint-Status Consumer-disputes  \
# 0              Closed with explanation               Yes
# 1      Closed with non-monetary relief                No
# 2              Closed with explanation                No
# 3              Closed with explanation                No
# 4              Closed with explanation                No
# 5              Closed with explanation               Yes
# 6              Closed with explanation                No
# 7              Closed with explanation                No
# 8              Closed with explanation               Yes
# 9      Closed with non-monetary relief                No
# 10             Closed with explanation                No
# 11             Closed with explanation                No
# 12     Closed with non-monetary relief                No
# 13             Closed with explanation                No
# 14                              Closed                No
# 15         Closed with monetary relief               NaN
# 16             Closed with explanation               NaN
# 17             Closed with explanation                No
# 18             Closed with explanation                No
# 19             Closed with explanation                No
# 20             Closed with explanation                No
# 21             Closed with explanation               NaN
# 22             Closed with explanation                No
# 23             Closed with explanation                No
# 24             Closed with explanation               Yes
# 25             Closed with explanation               NaN
# 26             Closed with explanation               Yes
# 27             Closed with explanation                No
# 28             Closed with explanation               NaN
# 29             Closed with explanation                No
# ...                                ...               ...
# 43236      Closed with monetary relief                No
# 43237          Closed with explanation                No
# 43238          Closed with explanation                No
# 43239      Closed with monetary relief                No
# 43240          Closed with explanation                No
# 43241          Closed with explanation                No
# 43242          Closed with explanation                No
# 43243          Closed with explanation               Yes
# 43244          Closed with explanation               Yes
# 43245          Closed with explanation                No
# 43246          Closed with explanation               Yes
# 43247          Closed with explanation                No
# 43248          Closed with explanation               Yes
# 43249          Closed with explanation                No
# 43250                           Closed                No
# 43251  Closed with non-monetary relief                No
# 43252          Closed with explanation                No
# 43253          Closed with explanation                No
# 43254          Closed with explanation               Yes
# 43255          Closed with explanation                No
# 43256          Closed with explanation                No
# 43257          Closed with explanation                No
# 43258          Closed with explanation               NaN
# 43259          Closed with explanation               Yes
# 43260          Closed with explanation               NaN
# 43261          Closed with explanation               NaN
# 43262          Closed with explanation                No
# 43263          Closed with explanation                No
# 43264          Closed with explanation               NaN
# 43265          Closed with explanation               NaN
#
#                               Consumer-complaint-summary
# 0      Seterus, Inc a déposé un faux rapport auprès d...
# 1      XX / XX / XXXX La requête en faillite n ° XXXX...
# 2      El XXXX / XXXX / 15, estaba preparando el vuel...
# 3      The loan was paid in XXXX XXXX. In XXXX, 4 yea...
# 4      J'ai obtenu un compte de crédit de soins pour ...
# 5      The owner of my original mortgage filed for ba...
# 6      J'ai été victime d'une fraude d'identité et j'...
# 7      Je suis en train de faire faillite et, par con...
# 8      Una agencia de cobranza me hizo adulterar de q...
# 9      Le XXXX / XXXX / 2015, j'ai reçu une réponse d...
# 10     My mortgage provider, United Wholesale Mortgag...
# 11     My boyfriend and I bought a XXXX sofa and we h...
# 12     Le XXXX XXXX, XXXX à environ XXXX heures, j’ai...
# 13     Both accounts below are settled and closed. Yo...
# 14     In XX / XX / XXXX we open a lease with XXXX DB...
# 15     I had scheduled a full TIME payment in their o...
# 16     He llamado a esta compañía muchas veces para i...
# 17     Todavía veo una deuda con Coast Professional e...
# 18     Never called or received any written notice of...
# 19     Cuando disputé con las agencias de crédito, so...
# 20     The use of the Gap Visa card issued by GE Capi...
# 21     Equifax a publié mes données via des systèmes ...
# 22     The mortgage loan was transferred from XXXX to...
# 23     Tengo menos de 30 días de retraso en mi pago. ...
# 24     In XX / XX / XXXX I pulled out my Equifax cred...
# 25     I was surprised when I reviewed my credit repo...
# 26     Abrí una cuenta de ahorros y cheques para jóve...
# 27     My XXXX account is up to date, I have been pay...
# 28     Transunion had a computer failure in which sev...
# 29     The debt of my wife is in charge, but they cal...
# ...                                                  ...
# 43236  My husband and I are in XXXX. I have been doin...
# 43237  My landlord applied to be approved for a short...
# 43238  I started a new loan with Wilshire consumer cr...
# 43239  Je me suis inscrit pour une carte de crédit sa...
# 43240  J'ai déposé une plainte auprès de CFPB et je d...
# 43241  J'ai déposé une plainte indiquant que les info...
# 43242  I sent XXXX XXXX XXXX a letter of validation o...
# 43243  I own a very small studio in XXXX XXXX, Illino...
# 43244  We are trying to divide a plot of land located...
# 43245  XXXX, I submitted documentation for a loan mod...
# 43246  SKIP TRACING, VARIOUS PLACES, COLLECTORS IN TH...
# 43247  XXXX complaint, NOT competent action taken fro...
# 43248  XXXX alias '' XXXX '' shows both in XXXX and i...
# 43249  The Joseph R. Harrison Company emphasizes that...
# 43250  I was in the process of selling my house and n...
# 43251  I have an American Express card from Macy's th...
# 43252  Cette dette du créancier initial XXXX XXXX XXX...
# 43253  This debt is eight years old and has not been ...
# 43254  THE COLLECTOR HAS NOT ADOPTED TO ADMINISTER HI...
# 43255  I had a mortgage through Greentree (Ditech) an...
# 43256  I started making extra principle payments to m...
# 43257  Compré un par de gafas para XXXX XXXX utilizan...
# 43258  Ils entrent en jugement contre moi et demanden...
# 43259  Bank of America ha iniciado una acción de ejec...
# 43260  My problem is with Experian. They continue to ...
# 43261  J'ai une demande non autorisée de Données fact...
# 43262  I called the company and they did not want to ...
# 43263  El prestamista no le proporcionó al cliente ni...
# 43264  The XXXX XXXX mortgage was transferred to Shel...
# 43265  This letter is related to account # XXXXXXXXX,...
#
# [43266 rows x 9 columns]

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
import json
import pickle
import urllib

from sklearn.preprocessing import LabelBinarizer

print(tf.__version__)
# Out:
# 1.12.0

# %%
data = data[pd.notnull(data['Consumer-complaint-summary'])]
data.head()
# Out:
#                   Complaint-Status  \
# 0          Closed with explanation
# 1  Closed with non-monetary relief
# 2          Closed with explanation
# 3          Closed with explanation
# 4          Closed with explanation
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Consumer-complaint-summary
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Seterus, Inc a déposé un faux rapport auprès des principaux bureaux de crédit XXXX, indiquant que mon prêt hypothécaire XXXX 2015 était en retard alors qu’ils recevaient le remboursement total du prêt le XXXX XXXX, 2015. Il convient de noter que les frais de retard ne sont pas évalués avant le XXXX du chacun selon les termes et conditions de notre contrat. Je suis incapable d'obtenir une hypothèque pour ma nouvelle maison en raison de leurs actions.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   XX / XX / XXXX La requête en faillite n ° XXXX du chapitre XXXX a été déposée à Hawaii et incluait le créancier XXXX XXXX pour un montant inconnu (supposé {540,00 $} XXXX.\nXX / XX / XXXX Chapitre XXXX Faillite acquittée # XXXX, y compris XXXX XXXX.\nXX / XX / XXXX - XXXX XXXX a continué à transférer les créances libérées aux agences de recouvrement. XXXX a supprimé XXXX XXXX XXXX XXXX mais Experian refuse de le faire.

# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   xx / xx / xxxx la requête en faillite n ° xxxx du chapitre xxxx a été déposée à hawaii et incluait le créancier xxxx xxxx pour un montant inconnu (supposé {540,00 $} xxxx.\nxx / xx / xxxx chapitre xxxx faillite acquittée # xxxx, y compris xxxx xxxx.\nxx / xx / xxxx - xxxx xxxx a continué à transférer les créances libérées aux agences de recouvrement. xxxx a supprimé xxxx xxxx xxxx xxxx mais experian refuse de le faire.
# 2  el xxxx / xxxx / 15, estaba preparando el vuelo de regreso a xxxx (vea xxxx) para el funeral de un familiar cercano y me alojé en un hotel en el aeropuerto xxxx. antes de irme, contraté a una cuidadora de perros y su amiga (que me habían referido personas que conocía) para que vigilaran mis perros xxxx en mi casa, recogieran mi correo y cuidaran mis plantas. le había dado a esta persona la llave de mi casa. en xxxx / xxxx / 15, vuelo a xxxx y no regresé a xxxx hasta la tarde de xxxx / xxxx / 15. cuando llegué a casa, me di cuenta de que mi tarjeta de débito se había utilizado para hacer aproximadamente xxxx compras desde mi cuenta de cheques con capital one 360. inmediatamente llamé y detuve mi tarjeta de débito, pero como había estado fuera durante más de una semana, no sabía qué había pasado. desde que ocurrió esto, luché con capital one con uñas y dientes, y aunque envié a capital one una declaración jurada notariada de que los cargos xxxx no son míos, una copia de mi itinerario...
# 3  the loan was paid in xxxx xxxx. in xxxx, 4 years after i moved from va (i moved in xxxx xx / xx / xxxx-6 months after paying the debt), a representative xxxx xxxx xxxx contacted me suddenly, indicating that my debt had not been paid and that i now owe them {$ 1100.00}. i explained that the debt was paid and, because so many years passed, i destroyed documents that i did not need to keep since the account was paid. in fact, if he owed the loan, xxxx xxxx xxxx had the right to cash the check in his possession, which he did not have because he had received it when the account was paid. that was something i asked them to provide me and they could not provide anything. despite my letter to them and the conversation on the phone, i was continually harassed and nothing was sent to me. then, in xxxx they contacted me through a collection letter for xxxx xxxx xxxx trying again to collect this debt. now there are two additional years, a total of 6 years after i paid the debt that xxxx xxxx x...
# 4  j'ai obtenu un compte de crédit de soins pour xxxx. immédiatement après avoir été facturé à tort par un autre médecin, je l'ai contacté pour me le faire savoir, au moment où il m'avait dit que j'étais responsable de cette charge et que je devais la régler moi-même et effectuer les paiements avant j'ai manqué. j'ai effectué les paiements et les frais ont été réglés par moi-même. je n'ai jamais été crédité pour cela et j'ai facturé des intérêts et des frais de retard. bien ce que j'ai payé, je l'ai ensuite utilisé aux fins prévues et j'ai obtenu xxxx dont j'avais besoin. eh bien, le bureau xxxx a eu du mal à les charger car je n’ai jamais reçu de carte physique.\nje paye donc et je reçois une notification l'informant que mon compte a été vendu à xxxx. je les appelle pour essayer de réparer ce gâchis et ils m'envoient à une agence de recouvrement de crédits xxxx xxxx xxxx. j'appelle xxxx à plusieurs reprises au cours de la journée et j'ai laissé des messages pour tenter de résoudre ce...

# %%
import re
data['Consumer-complaint-summary'] = data['Consumer-complaint-summary'].str.replace('x', '')
data['Consumer-complaint-summary'] = data['Consumer-complaint-summary'].str.replace('{', '')
data['Consumer-complaint-summary'] = data['Consumer-complaint-summary'].str.replace('}', '')
data['Consumer-complaint-summary'] = data['Consumer-complaint-summary'].str.replace('/', '')
data.head()
# Out:
#                   Complaint-Status  \
# 0          Closed with explanation
# 1  Closed with non-monetary relief
# 2          Closed with explanation
# 3          Closed with explanation
# 4          Closed with explanation
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Consumer-complaint-summary
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
],
#       dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43266 entries, 0 to 43265
# Data columns (total 2 columns):
# Complaint-Status              43266 non-null object
# Consumer-complaint-summary    43266 non-null object
# dtypes: object(2)
# memory usage: 1014.0+ KB

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43266 entries, 0 to 43265
# Data columns (total 2 columns):
# Complaint-Status              43266 non-null object
# Consumer-complaint-summary    43266 non-null object
# dtypes: object(2)
# memory usage: 1014.0+ KB

# %%
data_comp=data[['Consumer-complaint-summary']]
data_prod=data[['Complaint-Status']]

# %%
train_size = int(len(data_comp) * .999)

train_descriptions = data_comp[:train_size].astype('str')
train_prod = data_prod[:train_size]

test_descriptions = data_comp[train_size:].astype('str')
test_prod =data_prod[train_size:]

# %%
print(train_descriptions.shape)
print(test_descriptions.shape)
# Out:
# (43222, 1)
# (44, 1)

# %%
train_size = int(len(train_descriptions) * .8)

train_desc = train_descriptions[:train_size]
train_pr = train_prod[:train_size]

val_desc = train_descriptions[train_size:]
val_pr =train_prod[train_size:]

# %%
print(train_desc.shape)
print(val_desc.shape)
# Out:
# (34577, 1)
# (8645, 1)

# %%
print(train_pr.shape)
print(val_pr.shape)
# Out:
# (34577, 1)
# (8645, 1)

# %%
print(train_desc.info())
print(val_desc.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34577 entries, 0 to 34576
# Data columns (total 1 columns):
# Consumer-complaint-summary    34577 non-null object
# dtypes: object(1)
# memory usage: 540.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8645 entries, 34577 to 43221
# Data columns (total 1 columns):
# Consumer-complaint-summary    8645 non-null object
# dtypes: object(1)
# memory usage: 135.1+ KB
# None

# %%
from sklearn import preprocessing
encoder = preprocessing.LabelBinarizer()
encoder.fit_transform(train_pr)
train_encoded = encoder.transform(train_pr)
val_encoded = encoder.transform(val_pr)
num_classes = len(encoder.classes_)

# Print all possible products and the label for the first complaint in our training dataset
print(encoder.classes_)
print(train_encoded[0])
# Out:
# ['Closed' 'Closed with explanation' 'Closed with monetary relief'
#  'Closed with non-monetary relief' 'Untimely response']
# [0 1 0 0 0]

# %%
description_embeddings = hub.text_embedding_column("descriptions", module_spec="https://tfhub.dev/google/universal-sentence-encoder-large/3", trainable=False)

# %%
multi_label_head = tf.contrib.estimator.multi_label_head(
    num_classes,
    loss_reduction=tf.losses.Reduction.SUM_OVER_BATCH_SIZE
)

# %%
features = {
  "descriptions": np.array(train_desc).astype(np.str)
}
labels = np.array(train_encoded).astype(np.int32)
train_input_fn = tf.estimator.inputs.numpy_input_fn(features, labels, shuffle=True, batch_size=100, num_epochs=10)
estimator = tf.contrib.estimator.DNNEstimator(
    head=multi_label_head,
    hidden_units=[64,10],
    feature_columns=[description_embeddings])
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpvzp43iou
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpvzp43iou', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7feac02cdda0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# %%timeit
estimator.train(input_fn=train_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpvzp43iou/model.ckpt.
# INFO:tensorflow
# INFO:tensorflow:global_step/sec: 2.81707
# INFO:tensorflow:loss = 0.21778306, step = 12874 (35.495 sec)
# INFO:tensorflow:global_step/sec: 2.81329
# INFO:tensorflow:loss = 0.2398649, step = 12974 (35.549 sec)
# INFO:tensorflow:global_step/sec: 2.81591
# INFO:tensorflow:loss = 0.22902952, step = 13074 (35.512 sec)
# INFO:tensorflow:global_step/sec: 2.81462
# INFO:tensorflow:loss = 0.25572163, step = 13174 (35.529 sec)
# INFO:tensorflow:global_step/sec: 2.81102
# INFO:tensorflow:loss = 0.21119648, step = 13274 (35.575 sec)
# INFO:tensorflow:global_step/sec: 2.81277
# INFO:tensorflow:loss = 0.24079277, step = 13374 (35.551 sec)
# INFO:tensorflow:global_step/sec: 2.80336
# INFO:tensorflow:loss = 0.2143, step = 13474 (35.672 sec)
# INFO:tensorflow:global_step/sec: 2.80971
# INFO:tensorflow:loss = 0.23843588, step = 13574 (35.591 sec)
# INFO:tensorflow:global_step/sec: 2.8128
# INFO:tensorflow:loss = 0.23931299, step = 13674 (35.551 sec)
# INFO:tensorflow:Saving checkpoints for 13724 into /tmp/tmpvzp43iou/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.4062
# INFO:tensorflow:loss = 0.22454672, step = 13774 (41.558 sec)
# INFO:tensorflow:Saving checkpoints for 13832 into /tmp/tmpvzp43iou/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.28868487.
# 1 loop, best of 3: 21min 9s per loop

# %%
# %%timeit
train_input_fn_1 = tf.estimator.inputs.numpy_input_fn({"descriptions": np.array(train_desc).astype(np.str)}, train_encoded.astype(np.int32), shuffle=False)
estimator.evaluate(input_fn=train_input_fn_1)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-27-09:32:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpvzp43iou/model.ckpt-13832
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-27-09:34:14
# INFO:tensorflow:Saving dict for global step 13832: auc = 0.9397755, auc_precision_recall = 0.802395, average_loss = 0.23121001, global_step = 13832, loss = 0.23091117
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13832: /tmp/tmpvzp43iou/model.ckpt-13832
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-27-09:34:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpvzp43iou/model.ckpt-13832
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-27-09:36:28
# INFO:tensorflow:Saving dict for global step 13832: auc = 0.9397755, auc_precision_recall = 0.802395, average_loss = 0.23121001, global_step = 13832, loss = 0.23091117
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13832: /tmp/tmpvzp43iou/model.ckpt-13832
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-27-09:36:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpvzp43iou/model.ckpt-13832
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-27-09:38:39
# INFO:tensorflow:Saving dict for global step 13832: auc = 0.9397755, auc_precision_recall = 0.802395, average_loss = 0.23121001, global_step = 13832, loss = 0.23091117
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13832: /tmp/tmpvzp43iou/model.ckpt-13832
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-27-09:38:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpvzp43iou/model.ckpt-13832
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-27-09:40:51
# INFO:tensorflow:Saving dict for global step 13832: auc = 0.9397755, auc_precision_recall = 0.802395, average_loss = 0.23121001, global_step = 13832, loss = 0.23091117
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13832: /tmp/tmpvzp43iou/model.ckpt-13832
# 1 loop, best of 3: 2min 11s per loop

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn({"descriptions": np.array(val_desc).astype(np.str)}, val_encoded.astype(np.int32), shuffle=False)
estimator.evaluate(input_fn=eval_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-27-09:41:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpvzp43iou/model.ckpt-13832
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-27-09:41:38
# INFO:tensorflow:Saving dict for global step 13832: auc = 0.9403397, auc_precision_recall = 0.8006629, average_loss = 0.22961871, global_step = 13832, loss = 0.22939928
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13832: /tmp/tmpvzp43iou/model.ckpt-13832
# {'auc': 0.9403397,
#  'auc_precision_recall': 0.8006629,
#  'average_loss': 0.22961871,
#  'global_step': 13832,
#  'loss': 0.22939928}

# %%
predict_input_fn = tf.estimator.inputs.numpy_input_fn({"descriptions": np.array(test_descriptions).astype(np.str)}, shuffle=False)

results = estimator.predict(predict_input_fn)

# %%
# Display predictions
for product in results:
  top = product['probabilities'].argsort()[-1:]
  for prod in top:
    text_prod = encoder.classes_[prod]
    print(text_prod + ': ' + str(round(product['probabilities'][prod] * 100, 2)) + '%')
  print('')
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpvzp43iou/model.ckpt-13832
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Closed with explanation: 74.02%
#
# Closed with explanation: 87.4%
#
# Closed with explanation: 76.44%
#
# Closed with explanation: 74.69%
#
# Closed with explanation: 75.57%
#
# Closed with explanation: 76.84%
#
# Closed with explanation: 73.75%
#
# Closed with explanation: 74.43%
#
# Closed with explanation: 80.82%
#
# Closed with explanation: 85.34%
#
# Closed with explanation: 79.16%
#
# Closed with explanation: 79.06%
#
# Closed with explanation: 79.27%
#
# Closed with explanation: 86.21%
#
# Closed with explanation: 74.42%
#
# Closed with explanation: 90.92%
#
# Closed with explanation: 86.7%
#
# Closed with explanation: 76.88%
#
# Closed with explanation: 80.14%
#
# Closed with explanation: 83.46%
#
# Closed with explanation: 77.04%
#
# Closed with explanation: 90.43%
#
# Closed with explanation: 90.26%
#
# Closed with explanation: 86.59%
#
# Closed with explanation: 79.79%
#
# Closed with explanation: 85.55%
#
# Closed with explanation: 89.33%
#
# Closed with explanation: 88.98%
#
# Closed with explanation: 80.87%
#
# Closed with explanation: 48.96%
#
# Closed with explanation: 84.23%
#
# Closed with explanation: 91.14%
#
# Closed with explanation: 79.94%
#
# Closed with explanation: 89.57%
#
# Closed with explanation: 88.13%
#
# Closed with explanation: 79.22%
#
# Closed with explanation: 83.75%
#
# Closed with explanation: 78.09%
#
# Closed with explanation: 83.09%
#
# Closed with explanation: 77.73%
#
# Closed with explanation: 85.05%
#
# Closed with explanation: 84.08%
#
# Closed with explanation: 89.35%
#
# Closed with explanation: 84.01%

# %%
test_prod
# Out:
#                       Complaint-Status
# 43222  Closed with non-monetary relief
# 43223          Closed with explanation
# 43224          Closed with explanation
# 43225  Closed with non-monetary relief
# 43226      Closed with monetary relief
# 43227                           Closed
# 43228          Closed with explanation
# 43229      Closed with monetary relief
# 43230  Closed with non-monetary relief
# 43231          Closed with explanation
# 43232          Closed with explanation
# 43233          Closed with explanation
# 43234          Closed with explanation
# 43235          Closed with explanation
# 43236      Closed with monetary relief
# 43237          Closed with explanation
# 43238          Closed with explanation
# 43239      Closed with monetary relief
# 43240          Closed with explanation
# 43241          Closed with explanation
# 43242          Closed with explanation
# 43243          Closed with explanation
# 43244          Closed with explanation
# 43245          Closed with explanation
# 43246          Closed with explanation
# 43247          Closed with explanation
# 43248          Closed with explanation
# 43249          Closed with explanation
# 43250                           Closed
# 43251  Closed with non-monetary relief
# 43252          Closed with explanation
# 43253          Closed with explanation
# 43254          Closed with explanation
# 43255          Closed with explanation
# 43256          Closed with explanation
# 43257          Closed with explanation
# 43258          Closed with explanation
# 43259          Closed with explanation
# 43260          Closed with explanation
# 43261          Closed with explanation
# 43262          Closed with explanation
# 43263          Closed with explanation
# 43264          Closed with explanation
# 43265          Closed with explanation

# %% [markdown]
# **Prediction on test data**

# %%
fields= ['Consumer-complaint-summary'] 
test_data=pd.read_csv(zip_file.open('test.csv'),usecols=fields)
test_data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Consumer-complaint-summary
# 0  XXXX / XXXX / 16 I called Citibank to open a checking account with the promotional code of miles XXXX XXXX. I spoke with XXXX As part of the promotional fine, I had to comply with certain conditions of expense and payment of invoices. I met those, and I can provide evidence. As I did not have any proof that the promotion code applied correctly to my account, I sent a secure message to Citi to confirm it XX / XX / XXXX16. They replied that they could not see the account request to determine if a promotion code had been applied, but that if it were, they would be eligible for the promotion. Therefore, I continued to comply with the established requirements and paying a monthly fee for this checking account, based on this response. When the miles were not credited to my account, I got in touch with Citi. XX / XX / XXXX16, XXXX confirmed that a promotion code had been attached to my account, but that it was not intended for this. As Citi was unable to provide this information to me in ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            I'm struggling financially. I called and I offered to pay XXXX dollars a month for my debt until I could get back up. A-1 refused to accept my payment and said they would be garnishing my salary. He even said that I would sleep well at night knowing that I would not be able to eat if I got my salary.
# 2  In XXXX of 2015, an automatic payment was configured for the capital line with XXXX through our personal account XXXX, but the amount was incorrectly configured only because our first statement reflected the partial month. Our payments were made on the same day of each month in the amount of {$ 400.00} instead of {$ 680.00}, which was the correct amount. We have another mortgage with XXXX for which we have been making an additional payment of {$ 2000.00} per month during the last two years to reduce capital. The lender never notified us of the lack of payment by phone, text message or email, even though this information was provided (to me, my husband or my office), and never sent a late payment letter by mail until XX / XX / XXXX. Due to the failure of the lender to notify us properly. We have several mortgages with our businesses, lines of credit and credit cards and we have never been delayed in the last 25 years. Our credit score dropped almost XXXX points and the line closed. ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                             I submitted a request to XXXX, which is my current loan provider for my student loans. The request was for the forgiveness of public loans, so XXXX advanced the request to Fed Loans Servicing in XXXX XXXX. In XXXX XXXX, I received a letter from the Fed Loans that my application was under review. I also called the Fed Loans twice in both XXXX and XXXX. They told me that my application was being reviewed and I would like to know about them and not. I'm XXXX full-time with direct loans, so I qualify for the program. My employer filled out the paperwork.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       A state tax lien was filed against me XXXX / XXXX / XXXX, however, I was never notified of this. Then the tax was paid and XXXX / XXXX / XXXX was released. However, I was never notified of this matter and I paid it once it appeared on my credit. However, I believed that I have 3 years to file any tax amendments if necessary. I have disputed this for several years without luck. This appears on all my credit reports.

# %%
test_data = test_data[pd.notnull(test_data['Consumer-complaint-summary'])]

# %%
test_data.shape
# Out:
# (18543, 1)

# %%
pd.set_option('max_colwidth', 1000)
test_data['Consumer-complaint-summary'] = test_data['Consumer-complaint-summary'].str.lower()
test_data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Consumer-complaint-summary
# 0  xxxx / xxxx / 16 i called citibank to open a checking account with the promotional code of miles xxxx xxxx. i spoke with xxxx as part of the promotional fine, i had to comply with certain conditions of expense and payment of invoices. i met those, and i can provide evidence. as i did not have any proof that the promotion code applied correctly to my account, i sent a secure message to citi to confirm it xx / xx / xxxx16. they replied that they could not see the account request to determine if a promotion code had been applied, but that if it were, they would be eligible for the promotion. therefore, i continued to comply with the established requirements and paying a monthly fee for this checking account, based on this response. when the miles were not credited to my account, i got in touch with citi. xx / xx / xxxx16, xxxx confirmed that a promotion code had been attached to my account, but that it was not intended for this. as citi was unable to provide this information to me in ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            i'm struggling financially. i called and i offered to pay xxxx dollars a month for my debt until i could get back up. a-1 refused to accept my payment and said they would be garnishing my salary. he even said that i would sleep well at night knowing that i would not be able to eat if i got my salary.
# 2  in xxxx of 2015, an automatic payment was configured for the capital line with xxxx through our personal account xxxx, but the amount was incorrectly configured only because our first statement reflected the partial month. our payments were made on the same day of each month in the amount of {$ 400.00} instead of {$ 680.00}, which was the correct amount. we have another mortgage with xxxx for which we have been making an additional payment of {$ 2000.00} per month during the last two years to reduce capital. the lender never notified us of the lack of payment by phone, text message or email, even though this information was provided (to me, my husband or my office), and never sent a late payment letter by mail until xx / xx / xxxx. due to the failure of the lender to notify us properly. we have several mortgages with our businesses, lines of credit and credit cards and we have never been delayed in the last 25 years. our credit score dropped almost xxxx points and the line closed. ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                             i submitted a request to xxxx, which is my current loan provider for my student loans. the request was for the forgiveness of public loans, so xxxx advanced the request to fed loans servicing in xxxx xxxx. in xxxx xxxx, i received a letter from the fed loans that my application was under review. i also called the fed loans twice in both xxxx and xxxx. they told me that my application was being reviewed and i would like to know about them and not. i'm xxxx full-time with direct loans, so i qualify for the program. my employer filled out the paperwork.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       a state tax lien was filed against me xxxx / xxxx / xxxx, however, i was never notified of this. then the tax was paid and xxxx / xxxx / xxxx was released. however, i was never notified of this matter and i paid it once it appeared on my credit. however, i believed that i have 3 years to file any tax amendments if necessary. i have disputed this for several years without luck. this appears on all my credit reports.

# %%
test_data['Consumer-complaint-summary'] = test_data['Consumer-complaint-summary'].str.replace('x', '')
test_data['Consumer-complaint-summary'] = test_data['Consumer-complaint-summary'].str.replace('{', '')
test_data['Consumer-complaint-summary'] = test_data['Consumer-complaint-summary'].str.replace('}', '')
test_data['Consumer-complaint-summary'] = test_data['Consumer-complaint-summary'].str.replace('/', '')
test_data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Consumer-complaint-summary
# 0      16 i called citibank to open a checking account with the promotional code of miles  . i spoke with  as part of the promotional fine, i had to comply with certain conditions of epense and payment of invoices. i met those, and i can provide evidence. as i did not have any proof that the promotion code applied correctly to my account, i sent a secure message to citi to confirm it     16. they replied that they could not see the account request to determine if a promotion code had been applied, but that if it were, they would be eligible for the promotion. therefore, i continued to comply with the established requirements and paying a monthly fee for this checking account, based on this response. when the miles were not credited to my account, i got in touch with citi.     16,  confirmed that a promotion code had been attached to my account, but that it was not intended for this. as citi was unable to provide this information to me in , i went ahead, and only after they fulfilled t...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                i'm struggling financially. i called and i offered to pay  dollars a month for my debt until i could get back up. a-1 refused to accept my payment and said they would be garnishing my salary. he even said that i would sleep well at night knowing that i would not be able to eat if i got my salary.
# 2  in  of 2015, an automatic payment was configured for the capital line with  through our personal account , but the amount was incorrectly configured only because our first statement reflected the partial month. our payments were made on the same day of each month in the amount of $ 400.00 instead of $ 680.00, which was the correct amount. we have another mortgage with  for which we have been making an additional payment of $ 2000.00 per month during the last two years to reduce capital. the lender never notified us of the lack of payment by phone, tet message or email, even though this information was provided (to me, my husband or my office), and never sent a late payment letter by mail until     . due to the failure of the lender to notify us properly. we have several mortgages with our businesses, lines of credit and credit cards and we have never been delayed in the last 25 years. our credit score dropped almost  points and the line closed. if the lender had given us a fair cha...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 i submitted a request to , which is my current loan provider for my student loans. the request was for the forgiveness of public loans, so  advanced the request to fed loans servicing in  . in  , i received a letter from the fed loans that my application was under review. i also called the fed loans twice in both  and . they told me that my application was being reviewed and i would like to know about them and not. i'm  full-time with direct loans, so i qualify for the program. my employer filled out the paperwork.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      a state ta lien was filed against me     , however, i was never notified of this. then the ta was paid and      was released. however, i was never notified of this matter and i paid it once it appeared on my credit. however, i believed that i have 3 years to file any ta amendments if necessary. i have disputed this for several years without luck. this appears on all my credit reports.

# %%
test_data.dropna(inplace=True)

# %%
data_comp=test_data[['Consumer-complaint-summary']]
test_data_descriptions = data_comp[:test_data.size].astype('str')
data_prod=data[['Complaint-Status']]
test_data_prod = data_prod[:test_data.size]

# %%
predict_input_fn_test = tf.estimator.inputs.numpy_input_fn({"descriptions": np.array(test_data_descriptions).astype(np.str)}, shuffle=False)

results_test = estimator.predict(predict_input_fn_test)

# %%
# Display predictions

for product in results_test:
  top = product['probabilities'].argsort()[-1:]
  for prod in top:
    test_data_prod = encoder.classes_[prod]
    print(test_data_prod + ': ' + str(round(product['probabilities'][prod] * 100, 2)) + '%')
  print('')
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpvzp43iou/model.ckpt-13832
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Closed with explanation: 61.83%
#
# Closed with explanation: 88.52%
#
# Closed with explanation: 64.12%
#
# Closed with explanation: 90.45%
#
# Closed with explanation: 86.16%
#
# Closed with explanation: 51.97%
#
# Closed with explanation: 85.94%
#
# Closed with explanation: 91.66%
#
# Closed with explanation: 82.92%
#
# Closed with explanation: 77.81%
#
# Closed with explanation: 74.68%
#
# Closed with explanation: 89.07%
#
# Closed with explanation: 93.4%
#
# Closed with explanation: 77.94%
#
# Closed with explanation: 85.04%
#
# Closed with explanation: 78.77%
#
# Closed with explanation: 88.23%
#
# Closed with explanation: 66.35%
#
# Closed with explanation: 91.74%
#
# Closed with explanation: 74.17%
#
# Closed with explanation: 81.61%
#
# Closed with explanation: 77.17%
#
# Closed with explanation: 84.56%
#
# Closed with explanation: 76.5%
#
# Closed with explanation: 83.72%
#
# Closed with explanation: 88.43%
#
# Closed with explanation: 81.41%
#
# Closed with explanation: 88.53%
#
# Closed with explanation: 75.76%
#
# Closed with explanation: 90.39%
#
# Closed with explanation: 66.06%
#
# Closed with explanation: 85.39%
#
# Closed with explanation: 77.85%
#
# Closed with explanation: 90.28%
#
# Closed with explanation: 71.99%
#
# Closed with explanation: 71.52%
#
# Closed with explanation: 70.17%
#
# Closed with explanation: 64.38%
#
# Closed with explanation: 75.03%
#
# Closed with explanation: 48.72%
#
# Closed with explanation: 71.0%
#
# Closed with explanation: 84.34%
#
# Closed with explanation: 70.52%
#
# Closed with explanation: 63.55%
#
# Closed with explanation: 85.22%
#
# Closed with explanation: 76.55%
#
# Closed with explanation: 74.32%
#
# Closed with explanation: 85.37%
#
# Closed with explanation: 92.11%
#
# Closed with explanation: 92.26%
#
# Closed with explanation: 83.3%
#
# Closed with explanation: 91.05%
#
# Closed with explanation: 87.05%
#
# Closed with explanation: 78.87%
#
# Closed with explanation: 72.03%
#
# Closed with explanation: 82.84%
#
# Closed with explanation: 94.13%
#
# Closed with explanation: 77.42%
#
# Closed with explanation: 88.25%
#
# Closed with explanation: 55.88%
#
# Closed with explanation: 93.85%
#
# Closed with explanation: 79.44%
#
# Closed with explanation: 77.01%
#
# Closed with explanation: 88.77%
#
# Closed with explanation: 80.08%
#
# Closed with explanation: 77.87%
#
# Closed with explanation: 83.94%
#
# Closed with explanation: 83.56%
#
# Closed with explanation: 79.95%
#
# Closed with explanation: 85.69%
#
# Closed with explanation: 80.63%
#
# Closed with explanation: 88.83%
#
# Closed with explanation: 73.51%
#
# Closed with explanation: 81.86%
#
# Closed with explanation: 78.75%
#
# Closed with explanation: 93.32%
#
# Closed with explanation: 72.58%
#
# Closed with explanation: 86.94%
#
# Closed with explanation: 74.82%
#
# Closed with explanation: 82.27%
#
# Closed with explanation: 84.95%
#
# Closed with explanation: 89.87%
#
# Closed with explanation: 80.52%
#
# Closed with explanation: 68.55%
#
# Closed with explanation: 83.85%
#
# Closed with explanation: 83.66%
#
# Closed with explanation: 91.24%
#
# Closed with explanation: 79.62%
#
# Closed with explanation: 77.87%
#
# Closed with explanation: 87.33%
#
# Closed with explanation: 83.58%
#
# Closed with explanation: 83.45%
#
# Closed with explanation: 80.19%
#
# Closed with explanation: 83.45%
#
# Closed with explanation: 79.16%
#
# Closed with explanation: 72.84%
#
# Closed with explanation: 75.5%
#
# Closed with explanation: 76.36%
#
# Closed with explanation: 82.29%
#
# Closed with explanation: 87.6%
#
# Closed with explanation: 90.67%
#
# Closed with explanation: 85.82%
#
# Closed with explanation: 83.8%
#
# Closed with explanation: 79.0%
#
# Closed with explanation: 91.04%
#
# Closed with explanation: 88.47%
#
# Closed with explanation: 88.64%
#
# Closed with explanation: 74.54%
#
# Closed with explanation: 80.22%
#
# Closed with explanation: 70.05%
#
# Closed with explanation: 78.15%
#
# Closed with explanation: 68.6%
#
# Closed with explanation: 85.15%
#
# Closed with explanation: 83.56%
#
# Closed with explanation: 91.16%
#
# Closed with explanation: 88.43%
#
# Closed with explanation: 85.4%
#
# Closed with explanation: 84.68%
#
# Closed with explanation: 80.17%
#
# Closed with explanation: 58.84%
#
# Closed with explanation: 77.85%
#
# Closed with explanation: 90.56%
#
# Closed with explanation: 77.05%
#
# Closed with explanation: 80.23%
#
# Closed with explanation: 73.02%
#
# Closed with explanation: 80.61%
#
# Closed with explanation: 91.11%
#
# Closed with explanation: 80.53%
#
# Closed with explanation: 89.24%
#
# Closed with explanation: 79.78%
#
# Closed with explanation: 85.74%
#
# Closed with explanation: 75.47%
#
# Closed with explanation: 84.99%
#
# Closed with explanation: 79.34%
#
# Closed with explanation: 84.85%
#
# Closed with explanation: 79.81%
#
# Closed with explanation: 79.84%
#
# Closed with explanation: 53.52%
#
# Closed with explanation: 82.66%
#
# Closed with explanation: 88.03%
#
# Closed with explanation: 82.34%
#
# Closed with explanation: 78.75%
#
# Closed with explanation: 90.59%
#
# Closed with explanation: 77.52%
#
# Closed with explanation: 75.34%
#
# Closed with explanation: 74.34%
#
# Closed with explanation: 83.95%
#
# Closed with explanation: 66.21%
#
# Closed with explanation: 69.88%
#
# Closed with explanation: 83.81%
#
# Closed with explanation: 86.77%
#
# Closed with explanation: 91.35%
#
# Closed with explanation: 79.62%
#
# Closed with explanation: 61.34%
#
# Closed with explanation: 73.56%
#
# Closed with explanation: 83.4%
#
# Closed with explanation: 91.43%
#
# Closed with explanation: 86.6%
#
# Closed with explanation: 80.48%
#
# Closed with explanation: 85.93%
#
# Closed with explanation: 84.39%
#
# Closed with explanation: 79.24%
#
# Closed with explanation: 89.03%
#
# Closed with explanation: 80.17%
#
# Closed with explanation: 93.61%
#
# Closed with explanation: 71.74%
#
# Closed with explanation: 85.32%
#
# Closed with explanation: 89.42%
#
# Closed with explanation: 76.65%
#
# Closed with explanation: 74.56%
#
# Closed with explanation: 77.34%
#
# Closed with explanation: 62.03%
#
# Closed with explanation: 79.59%
#
# Closed with explanation: 84.47%
#
# Closed with explanation: 85.32%
#
# Closed with explanation: 87.02%
#
# Closed with explanation: 49.94%
#
# Closed with explanation: 75.07%
#
# Closed with explanation: 82.98%
#
# Closed with explanation: 80.5%
#
# Closed with explanation: 67.91%
#
# Closed with explanation: 78.39%
#
# Closed with explanation: 90.21%
#
# Closed with explanation: 78.61%
#
# Closed with explanation: 79.55%
#
# Closed with explanation: 78.29%
#
# Closed with explanation: 57.5%
#
# Closed with explanation: 75.21%
#
# Closed with explanation: 90.95%
#
# Closed with explanation: 75.99%
#
# Closed with explanation: 83.18%
#
# Closed with explanation: 60.54%
#
# Closed with explanation: 79.54%
#
# Closed with explanation: 80.76%
#
# Closed with explanation: 78.08%
#
# Closed with explanation: 65.24%
#
# Closed with explanation: 87.76%
#
# Closed with explanation: 79.2%
#
# Closed with explanation: 91.07%
#
# Closed with explanation: 79.02%
#
# Closed with explanation: 89.45%
#
# Closed with explanation: 74.28%
#
# Closed with explanation: 83.69%
#
# Closed with explanation: 67.74%
#
# Closed with explanation: 91.99%
#
# Closed with explanation: 67.57%
#
# Closed with explanation: 76.37%
#
# Closed with explanation: 85.77%
#
# Closed with explanation: 67.33%
#
# Closed with explanation: 69.5%
#
# Closed with explanation: 78.84%
#
# Closed with explanation: 82.16%
#
# Closed with explanation: 73.16%
#
# Closed with explanation: 73.0%
#
# Closed with explanation: 59.29%
#
# Closed with explanation: 83.3%
#
# Closed with explanation: 91.93%
#
# Closed with explanation: 82.55%
#
# Closed with explanation: 81.0%
#
# Closed with explanation: 52.94%
#
# Closed with explanation: 76.0%
#
# Closed with explanation: 54.64%
#
# Closed with explanation: 55.99%
#
# Closed with explanation: 79.39%
#
# Closed with explanation: 79.87%
#
# Closed with explanation: 94.39%
#
# Closed with explanation: 70.22%
#
# Closed with explanation: 91.52%
#
# Closed with explanation: 78.3%
#
# Closed with explanation: 91.77%
#
# Closed with explanation: 89.19%
#
# Closed with explanation: 69.74%
#
# Closed with explanation: 68.52%
#
# Closed with explanation: 79.66%
#
# Closed with explanation: 83.69%
#
# Closed with explanation: 76.39%
#
# Closed with explanation: 60.54%
#
# Closed with explanation: 62.19%
#
# Closed with explanation: 65.68%
#
# Closed with explanation: 79.29%
#
# Closed with explanation: 63.16%
#
# Closed with explanation: 64.64%
#
# Closed with explanation: 86.84%
#
# Closed with explanation: 85.49%
#
# Closed with explanation: 89.61%
#
# Closed with explanation: 77.58%
#
# Closed with explanation: 92.38%
#
# Closed with explanation: 86.23%
#
# Closed with explanation: 87.15%
#
# Closed with explanation: 91.67%
#
# Closed with explanation: 85.49%
#
# Closed with explanation: 76.96%
#
# Closed with explanation: 54.29%
#
# Closed with explanation: 83.96%
#
# Closed with explanation: 86.38%
#
# Closed with explanation: 68.04%
#
# Closed with explanation: 93.39%
#
# Closed with explanation: 77.05%
#
# Closed with explanation: 94.06%
#
# Closed with explanation: 79.33%
#
# Closed with explanation: 87.45%
#
# Closed with explanation: 84.51%
#
# Closed with explanation: 84.14%
#
# Closed with explanation: 68.93%
#
# Closed with explanation: 82.52%
#
# Closed with explanation: 61.35%
#
# Closed with explanation: 66.21%
#
# Closed with explanation: 83.97%
#
# Closed with explanation: 78.43%
#
# Closed with explanation: 78.94%
#
# Closed with explanation: 69.62%
#
# Closed with explanation: 77.24%
#
# Closed with explanation: 76.85%
#
# Closed with explanation: 88.75%
#
# Closed with explanation: 89.93%
#
# Closed with explanation: 79.75%
#
# Closed with explanation: 61.85%
#
# Closed with explanation: 55.31%
#
# Closed with explanation: 82.6%
#
# Closed with explanation: 70.6%
#
# Closed with explanation: 70.22%
#
# Closed with explanation: 77.61%
#
# Closed with explanation: 93.23%
#
# Closed with explanation: 73.99%
#
# Closed with explanation: 63.77%
#
# Closed with explanation: 89.84%
#
# Closed with explanation: 82.09%
#
# Closed with explanation: 86.26%
#
# Closed with explanation: 78.52%
#
# Closed with explanation: 83.08%
#
# Closed with explanation: 74.19%
#
# Closed with explanation: 79.04%
#
# Closed with explanation: 79.11%
#
# Closed with explanation: 77.58%
#
# Closed with explanation: 85.58%
#
# Closed with explanation: 84.25%
#
# Closed with explanation: 89.84%
#
# Closed with explanation: 81.98%
#
# Closed with explanation: 81.92%
#
# Closed with explanation: 77.7%
#
# Closed with explanation: 84.53%
#
# Closed with explanation: 78.94%
#
# Closed with explanation: 87.85%
#
# Closed with monetary relief: 58.4%
#
# Closed with explanation: 58.62%
#
# Closed with explanation: 78.67%
#
# Closed with explanation: 88.74%
#
# Closed with explanation: 68.8%
#
# Closed with explanation: 86.55%
#
# Closed with explanation: 83.94%
#
# Closed with explanation: 75.43%
#
# Closed with explanation: 90.46%
#
# Closed with explanation: 76.92%
#
# Closed with explanation: 83.76%
#
# Closed with explanation: 63.24%
#
# Closed with explanation: 92.85%
#
# Closed with explanation: 64.09%
#
# Closed with explanation: 79.14%
#
# Closed with explanation: 84.64%
#
# Closed with explanation: 75.99%
#
# Closed with explanation: 69.57%
#
# Closed with explanation: 88.47%
#
# Closed with explanation: 88.72%
#
# Closed with explanation: 92.5%
#
# Closed with explanation: 85.17%
#
# Closed with explanation: 81.01%
#
# Closed with explanation: 70.04%
#
# Closed with explanation: 63.26%
#
# Closed with explanation: 93.24%
#
# Closed with explanation: 87.38%
#
# Closed with explanation: 93.54%
#
# Closed with explanation: 76.79%
#
# Closed with explanation: 86.59%
#
# Closed with explanation: 83.48%
#
# Closed with explanation: 62.94%
#
# Closed with explanation: 83.37%
#
# Closed with explanation: 86.26%
#
# Closed with explanation: 86.57%
#
# Closed with explanation: 83.52%
#
# Closed with explanation: 86.43%
#
# Closed with explanation: 84.13%
#
# Closed with explanation: 78.62%
#
# Closed with explanation: 83.2%
#
# Closed with explanation: 80.28%
#
# Closed with explanation: 82.43%
#
# Closed with explanation: 85.07%
#
# Closed with explanation: 79.77%
#
# Closed with explanation: 78.37%
#
# Closed with explanation: 65.34%
#
# Closed with explanation: 67.37%
#
# Closed with explanation: 90.15%
#
# Closed with explanation: 85.13%
#
# Closed with explanation: 83.74%
#
# Closed with explanation: 85.76%
#
# Closed with explanation: 82.64%
#
# Closed with explanation: 73.77%
#
# Closed with explanation: 79.15%
#
# Closed with explanation: 78.79%
#
# Closed with explanation: 92.72%
#
# Closed with explanation: 79.54%
#
# Closed with explanation: 82.96%
#
# Closed with explanation: 82.88%
#
# Closed with explanation: 87.89%
#
# Closed with explanation: 88.09%
#
# Closed with explanation: 81.81%
#
# Closed with explanation: 63.98%
#
# Closed with explanation: 74.16%
#
# Closed with explanation: 71.62%
#
# Closed with explanation: 88.16%
#
# Closed with explanation: 64.77%
#
# Closed with explanation: 78.62%
#
# Closed with explanation: 78.85%
#
# Closed with explanation: 89.65%
#
# Closed with explanation: 92.87%
#
# Closed with explanation: 77.56%
#
# Closed with explanation: 76.39%
#
# Closed with explanation: 77.46%
#
# Closed with explanation: 80.21%
#
# Closed with explanation: 84.97%
#
# Closed with explanation: 83.67%
#
# Closed with explanation: 89.67%
#
# Closed with explanation: 76.49%
#
# Closed with explanation: 70.73%
#
# Closed with explanation: 65.66%
#
# Closed with explanation: 85.6%
#
# Closed with explanation: 72.35%
#
# Closed with explanation: 84.42%
#
# Closed with explanation: 92.28%
#
# Closed with explanation: 76.85%
#
# Closed with explanation: 80.51%
#
# Closed with explanation: 75.41%
#
# Closed with explanation: 76.84%
#
# Closed with explanation: 78.33%
#
# Closed with explanation: 69.06%
#
# Closed with explanation: 75.38%
#
# Closed with explanation: 84.04%
#
# Closed with explanation: 81.28%
#
# Closed with explanation: 75.38%
#
# Closed with explanation: 77.69%
#
# Closed with explanation: 73.47%
#
# Closed with explanation: 78.95%
#
# Closed with explanation: 82.76%
#
# Closed with explanation: 87.63%
#
# Closed with explanation: 86.71%
#
# Closed with explanation: 67.54%
#
# Closed with explanation: 77.3%
#
# Closed with explanation: 79.27%
#
# Closed with explanation: 68.8%
#
# Closed with explanation: 83.87%
#
# Closed with explanation: 76.61%
#
# Closed with explanation: 81.55%
#
# Closed with explanation: 64.12%
#
# Closed with explanation: 82.93%
#
# Closed with explanation: 93.0%
#
# Closed with explanation: 84.54%
#
# Closed with explanation: 76.63%
#
# Closed with explanation: 91.15%
#
# Closed with explanation: 87.88%
#
# Closed with explanation: 79.29%
#
# Closed with explanation: 88.62%
#
# Closed with explanation: 77.72%
#
# Closed with explanation: 86.81%
#
# Closed with explanation: 86.02%
#
# Closed with explanation: 82.79%
#
# Closed with explanation: 92.34%
#
# Closed with explanation: 77.2%
#
# Closed with explanation: 61.56%
#
# Closed with explanation: 87.73%
#
# Closed with explanation: 77.16%
#
# Closed with explanation: 73.67%
#
# Closed with explanation: 77.79%
#
# Closed with explanation: 73.6%
#
# Closed with explanation: 80.52%
#
# Closed with explanation: 67.31%
#
# Closed with explanation: 61.65%
#
# Closed with explanation: 85.05%
#
# Closed with explanation: 93.73%
#
# Closed with explanation: 79.95%
#
# Closed with explanation: 82.6%
#
# Closed with explanation: 81.14%
#
# Closed with explanation: 57.14%
#
# Closed with explanation: 80.32%
#
# Closed with explanation: 72.35%
#
# Closed with explanation: 80.38%
#
# Closed with explanation: 79.16%
#
# Closed with explanation: 89.48%
#
# Closed with explanation: 85.22%
#
# Closed with explanation: 80.46%
#
# Closed with explanation: 76.43%
#
# Closed with explanation: 80.11%
#
# Closed with explanation: 88.61%
#
# Closed with explanation: 91.81%
#
# Closed with explanation: 83.15%
#
# Closed with explanation: 65.28%
#
# Closed with explanation: 93.38%
#
# Closed with explanation: 89.39%
#
# Closed with explanation: 79.85%
#
# Closed with explanation: 82.47%
#
# Closed with explanation: 73.49%
#
# Closed with explanation: 89.95%
#
# Closed with explanation: 92.18%
#
# Closed with explanation: 76.86%
#
# Closed with explanation: 80.51%
#
# Closed with explanation: 92.01%
#
# Closed with explanation: 79.94%
#
# Closed with explanation: 76.67%
#
# Closed with explanation: 58.99%
#
# Closed with explanation: 77.31%
#
# Closed with explanation: 91.94%
#
# Closed with explanation: 73.34%
#
# Closed with explanation: 88.96%
#
# Closed with explanation: 85.82%
#
# Closed with explanation: 78.87%
#
# Closed with explanation: 82.21%
#
# Closed with explanation: 81.66%
#
# Closed with explanation: 77.32%
#
# Closed with explanation: 93.47%
#
# Closed with explanation: 79.38%
#
# Closed with explanation: 90.39%
#
# Closed with explanation: 53.83%
#
# Closed with explanation: 67.8%
#
# Closed with explanation: 87.92%
#
# Closed with explanation: 82.57%
#
# Closed with explanation: 90.02%
#
# Closed with explanation: 86.35%
#
# Closed with explanation: 57.95%
#
# Closed with explanation: 91.6%
#
# Closed with explanation: 80.99%
#
# Closed with explanation: 66.1%
#
# Closed with explanation: 87.79%
#
# Closed with explanation: 70.12%
#
# Closed with explanation: 77.51%
#
# Closed with explanation: 82.95%
#
# Closed with explanation: 88.12%
#
# Closed with explanation: 75.55%
#
# Closed with explanation: 85.47%
#
# Closed with explanation: 69.27%
#
# Closed with explanation: 75.49%
#
# Closed with explanation: 92.62%
#
# Closed with explanation: 55.95%
#
# Closed with explanation: 78.65%
#
# Closed with explanation: 88.0%
#
# Closed with explanation: 85.78%
#
# Closed with explanation: 81.19%
#
# Closed with explanation: 89.8%
#
# Closed with explanation: 82.21%
#
# Closed with explanation: 65.05%
#
# Closed with explanation: 65.71%
#
# Closed with explanation: 80.4%
#
# Closed with explanation: 55.49%
#
# Closed with explanation: 89.3%
#
# Closed with explanation: 78.68%
#
# Closed with explanation: 92.54%
#
# Closed with explanation: 89.53%
#
# Closed with explanation: 83.9%
#
# Closed with explanation: 93.7%
#
# Closed with explanation: 74.1%
#
# Closed with explanation: 89.57%
#
# Closed with explanation: 81.36%
#
# Closed with explanation: 82.32%
#
# Closed with explanation: 75.17%
#
# Closed with explanation: 83.62%
#
# Closed with explanation: 77.37%
#
# Closed with explanation: 84.61%
#
# Closed with explanation: 89.5%
#
# Closed with explanation: 79.86%
#
# Closed with explanation: 82.05%
#
# Closed with explanation: 68.82%
#
# Closed with explanation: 73.64%
#
# Closed with explanation: 76.24%
#
# Closed with explanation: 59.71%
#
# Closed with explanation: 87.74%
#
# Closed with explanation: 88.46%
#
# Closed with explanation: 77.5%
#
# Closed with explanation: 89.15%
#
# Closed with explanation: 78.8%
#
# Closed with explanation: 83.72%
#
# Closed with explanation: 48.32%
#
# Closed with explanation: 76.55%
#
# Closed with explanation: 65.98%
#
# Closed with explanation: 82.23%
#
# Closed with explanation: 82.49%
#
# Closed with explanation: 72.7%
#
# Closed with explanation: 76.41%
#
# Closed with explanation: 93.43%
#
# Closed with explanation: 59.61%
#
# Closed with explanation: 72.04%
#
# Closed with explanation: 84.29%
#
# Closed with explanation: 86.92%
#
# Closed with explanation: 79.64%
#
# Closed with explanation: 94.05%
#
# Closed with explanation: 76.57%
#
# Closed with explanation: 73.2%
#
# Closed with explanation: 76.88%
#
# Closed with explanation: 70.85%
#
# Closed with explanation: 82.97%
#
# Closed with explanation: 69.02%
#
# Closed with explanation: 84.13%
#
# Closed with explanation: 74.22%
#
# Closed with explanation: 79.43%
#
# Closed with explanation: 75.85%
#
# Closed with explanation: 88.25%
#
# Closed with explanation: 83.45%
#
# Closed with explanation: 76.21%
#
# Closed with explanation: 81.25%
#
# Closed with explanation: 85.06%
#
# Closed with explanation: 87.12%
#
# Closed with explanation: 83.24%
#
# Closed with explanation: 80.59%
#
# Closed with explanation: 64.15%
#
# Closed with explanation: 72.05%
#
# Closed with explanation: 70.98%
#
# Closed with explanation: 81.56%
#
# Closed with explanation: 92.45%
#
# Closed with explanation: 76.06%
#
# Closed with explanation: 77.49%
#
# Closed with explanation: 79.26%
#
# Closed with explanation: 92.53%
#
# Closed with explanation: 81.85%
#
# Closed with explanation: 83.78%
#
# Closed with explanation: 80.57%
#
# Closed with explanation: 76.37%
#
# Closed with explanation: 80.99%
#
# Closed with explanation: 64.13%
#
# Closed with explanation: 86.62%
#
# Closed with explanation: 83.99%
#
# Closed with explanation: 67.93%
#
# Closed with explanation: 87.16%
#
# Closed with explanation: 75.55%
#
# Closed with explanation: 81.89%
#
# Closed with explanation: 72.34%
#
# Closed with explanation: 73.56%
#
# Closed with explanation: 90.42%
#
# Closed with explanation: 66.21%
#
# Closed with explanation: 79.23%
#
# Closed with explanation: 80.19%
#
# Closed with explanation: 75.08%
#
# Closed with explanation: 85.77%
#
# Closed with explanation: 70.58%
#
# Closed with explanation: 82.12%
#
# Closed with explanation: 69.37%
#
# Closed with explanation: 91.19%
#
# Closed with explanation: 87.91%
#
# Closed with explanation: 77.34%
#
# Closed with explanation: 90.6%
#
# Closed with explanation: 78.23%
#
# Closed with explanation: 92.02%
#
# Closed with explanation: 92.67%
#
# Closed with explanation: 85.47%
#
# Closed with explanation: 80.06%
#
# Closed with explanation: 91.14%
#
# Closed with explanation: 55.79%
#
# Closed with explanation: 70.62%
#
# Closed with explanation: 66.78%
#
# Closed with explanation: 92.98%
#
# Closed with explanation: 86.43%
#
# Closed with explanation: 81.48%
#
# Closed with explanation: 75.45%
#
# Closed with explanation: 63.68%
#
# Closed with explanation: 83.58%
#
# Closed with explanation: 88.19%
#
# Closed with explanation: 78.05%
#
# Closed with explanation: 81.75%
#
# Closed with explanation: 85.25%
#
# Closed with explanation: 84.14%
#
# Closed with explanation: 87.51%
#
# Closed with explanation: 56.07%
#
# Closed with explanation: 81.97%
#
# Closed with explanation: 92.27%
#
# Closed with explanation: 76.39%
#
# Closed with explanation: 61.22%
#
# Closed with explanation: 76.8%
#
# Closed with explanation: 63.97%
#
# Closed with explanation: 82.16%
#
# Closed with explanation: 79.49%
#
# Closed with explanation: 74.67%
#
# Closed with explanation: 93.41%
#
# Closed with explanation: 73.66%
#
# Closed with explanation: 67.04%
#
# Closed with explanation: 82.33%
#
# Closed with explanation: 88.27%
#
# Closed with explanation: 86.43%
#
# Closed with explanation: 76.85%
#
# Closed with explanation: 84.59%
#
# Closed with explanation: 79.67%
#
# Closed with explanation: 83.25%
#
# Closed with explanation: 61.79%
#
# Closed with explanation: 91.43%
#
# Closed with explanation: 74.29%
#
# Closed with explanation: 84.76%
#
# Closed with explanation: 87.08%
#
# Closed with explanation: 83.43%
#
# Closed with explanation: 67.7%
#
# Closed with explanation: 52.35%
#
# Closed with explanation: 86.42%
#
# Closed with explanation: 64.47%
#
# Closed with explanation: 92.82%
#
# Closed with explanation: 77.82%
#
# Closed with explanation: 75.82%
#
# Closed with explanation: 66.06%
#
# Closed with explanation: 86.89%
#
# Closed with explanation: 86.68%
#
# Closed with explanation: 84.07%
#
# Closed with explanation: 89.14%
#
# Closed with explanation: 72.45%
#
# Closed with explanation: 83.81%
#
# Closed with explanation: 72.57%
#
# Closed with explanation: 80.55%
#
# Closed with explanation: 71.28%
#
# Closed with explanation: 80.22%
#
# Closed with explanation: 93.64%
#
# Closed with explanation: 67.04%
#
# Closed with explanation: 86.27%
#
# Closed with explanation: 80.79%
#
# Closed with explanation: 80.16%
#
# Closed with explanation: 80.74%
#
# Closed with explanation: 79.26%
#
# Closed with explanation: 93.95%
#
# Closed with explanation: 91.46%
#
# Closed with explanation: 82.61%
#
# Closed with explanation: 89.09%
#
# Closed with explanation: 91.74%
#
# Closed with explanation: 67.63%
#
# Closed with explanation: 91.6%
#
# Closed with explanation: 62.4%
#
# Closed with explanation: 83.51%
#
# Closed with explanation: 75.63%
#
# Closed with explanation: 90.74%
#
# Closed with explanation: 69.3%
#
# Closed with explanation: 91.0%
#
# Closed with explanation: 93.47%
#
# Closed with explanation: 87.65%
#
# Closed with explanation: 83.15%
#
# Closed with explanation: 88.28%
#
# Closed with explanation: 79.1%
#
# Closed with explanation: 88.17%
#
# Closed with explanation: 70.54%
#
# Closed with explanation: 81.35%
#
# Closed with explanation: 80.07%
#
# Closed with explanation: 89.12%
#
# Closed with explanation: 92.46%
#
# Closed with explanation: 86.32%
#
# Closed with explanation: 81.48%
#
# Closed with explanation: 87.5%
#
# Closed with explanation: 88.78%
#
# Closed with explanation: 78.7%
#
# Closed with explanation: 87.83%
#
# Closed with explanation: 80.1%
#
# Closed with explanation: 80.28%
#
# Closed with explanation: 68.49%
#
# Closed with explanation: 76.54%
#
# Closed with explanation: 72.65%
#
# Closed with explanation: 79.16%
#
# Closed with explanation: 90.7%
#
# Closed with explanation: 81.85%
#
# Closed with explanation: 86.24%
#
# Closed with explanation: 83.39%
#
# Closed with explanation: 74.09%
#
# Closed with explanation: 88.41%
#
# Closed with explanation: 78.52%
#
# Closed with explanation: 75.69%
#
# Closed with explanation: 79.77%
#
# Closed with explanation: 71.2%
#
# Closed with explanation: 78.82%
#
# Closed with explanation: 83.94%
#
# Closed with explanation: 72.88%
#
# Closed with explanation: 79.2%
#
# Closed with explanation: 73.45%
#
# Closed with explanation: 71.74%
#
# Closed with explanation: 74.3%
#
# Closed with explanation: 80.46%
#
# Closed with explanation: 90.66%
#
# Closed with explanation: 65.44%
#
# Closed with explanation: 73.66%
#
# Closed with explanation: 94.21%
#
# Closed with explanation: 79.94%
#
# Closed with explanation: 74.52%
#
# Closed with explanation: 86.67%
#
# Closed with explanation: 78.55%
#
# Closed with explanation: 92.87%
#
# Closed with explanation: 88.0%
#
# Closed with explanation: 71.49%
#
# Closed with explanation: 75.49%
#
# Closed with explanation: 63.41%
#
# Closed with explanation: 70.07%
#
# Closed with explanation: 81.57%
#
# Closed with explanation: 84.8%
#
# Closed with explanation: 75.29%
#
# Closed with explanation: 84.36%
#
# Closed with explanation: 76.68%
#
# Closed with explanation: 81.47%
#
# Closed with explanation: 77.41%
#
# Closed with explanation: 91.43%
#
# Closed with explanation: 86.72%
#
# Closed with explanation: 83.0%
#
# Closed with explanation: 92.29%
#
# Closed with explanation: 77.31%
#
# Closed with explanation: 87.92%
#
# Closed with explanation: 80.48%
#
# Closed with explanation: 88.5%
#
# Closed with explanation: 78.65%
#
# Closed with explanation: 84.24%
#
# Closed with explanation: 77.79%
#
# Closed with explanation: 84.71%
#
# Closed with explanation: 79.5%
#
# Closed with explanation: 63.55%
#
# Closed with explanation: 79.0%
#
# Closed with explanation: 70.26%
#
# Closed with explanation: 73.24%
#
# Closed with explanation: 92.17%
#
# Closed with explanation: 77.13%
#
# Closed with explanation: 61.6%
#
# Closed with explanation: 76.97%
#
# Closed with explanation: 81.82%
#
# Closed with explanation: 80.36%
#
# Closed with explanation: 79.01%
#
# Closed with explanation: 85.39%
#
# Closed with explanation: 82.19%
#
# Closed with explanation: 85.77%
#
# Closed with explanation: 63.11%
#
# Closed with explanation: 77.75%
#
# Closed with explanation: 64.84%
#
# Closed with explanation: 77.99%
#
# Closed with explanation: 77.17%
#
# Closed with explanation: 80.13%
#
# Closed with explanation: 76.22%
#
# Closed with explanation: 74.85%
#
# Closed with explanation: 93.08%
#
# Closed with explanation: 83.32%
#
# Closed with explanation: 85.46%
#
# Closed with explanation: 56.26%
#
# Closed with explanation: 85.94%
#
# Closed with explanation: 75.32%
#
# Closed with explanation: 89.29%
#
# Closed with explanation: 64.87%
#
# Closed with explanation: 69.78%
#
# Closed with explanation: 91.99%
#
# Closed with explanation: 55.72%
#
# Closed with explanation: 80.61%
#
# Closed with explanation: 62.87%
#
# Closed with explanation: 79.0%
#
# Closed with explanation: 89.69%
#
# Closed with explanation: 72.77%
#
# Closed with explanation: 82.89%
#
# Closed with explanation: 82.64%
#
# Closed with explanation: 79.13%
#
# Closed with explanation: 92.84%
#
# Closed with explanation: 70.81%
#
# Closed with explanation: 79.4%
#
# Closed with explanation: 84.17%
#
# Closed with explanation: 85.88%
#
# Closed with explanation: 90.08%
#
# Closed with explanation: 83.57%
#
# Closed with explanation: 83.22%
#
# Closed with explanation: 64.86%
#
# Closed with explanation: 79.58%
#
# Closed with explanation: 80.61%
#
# Closed with explanation: 62.98%
#
# Closed with explanation: 73.6%
#
# Closed with explanation: 89.93%
#
# Closed with explanation: 82.42%
#
# Closed with monetary relief: 55.16%
#
# Closed with explanation: 74.42%
#
# Closed with explanation: 75.47%
#
# Closed with explanation: 89.36%
#
# Closed with explanation: 59.73%
#
# Closed with explanation: 84.02%
#
# Closed with explanation: 92.04%
#
# Closed with explanation: 85.72%
#
# Closed with explanation: 64.43%
#
# Closed with explanation: 84.09%
#
# Closed with explanation: 86.22%
#
# Closed with explanation: 89.47%
#
# Closed with explanation: 78.78%
#
# Closed with explanation: 79.26%
#
# Closed with explanation: 75.38%
#
# Closed with explanation: 74.36%
#
# Closed with explanation: 91.08%
#
# Closed with explanation: 69.66%
#
# Closed with explanation: 66.9%
#
# Closed with explanation: 84.61%
#
# Closed with explanation: 74.52%
#
# Closed with explanation: 73.21%
#
# Closed with explanation: 79.26%
#
# Closed with explanation: 86.33%
#
# Closed with explanation: 82.13%
#
# Closed with explanation: 87.98%
#
# Closed with explanation: 90.19%
#
# Closed with explanation: 88.88%
#
# Closed with explanation: 92.87%
#
# Closed with explanation: 88.06%
#
# Closed with explanation: 82.32%
#
# Closed with explanation: 91.96%
#
# Closed with explanation: 81.91%
#
# Closed with explanation: 90.12%
#
# Closed with explanation: 55.24%
#
# Closed with explanation: 79.2%
#
# Closed with explanation: 69.8%
#
# Closed with explanation: 75.22%
#
# Closed with explanation: 85.3%
#
# Closed with explanation: 69.42%
#
# Closed with explanation: 73.88%
#
# Closed with explanation: 73.38%
#
# Closed with explanation: 83.54%
#
# Closed with explanation: 89.12%
#
# Closed with explanation: 79.05%
#
# Closed with explanation: 93.64%
#
# Closed with explanation: 85.82%
#
# Closed with explanation: 83.54%
#
# Closed with explanation: 83.36%
#
# Closed with explanation: 64.65%
#
# Closed with explanation: 76.87%
#
# Closed with explanation: 84.68%
#
# Closed with explanation: 94.07%
#
# Closed with explanation: 90.22%
#
# Closed with explanation: 77.06%
#
# Closed with explanation: 78.68%
#
# Closed with explanation: 94.43%
#
# Closed with explanation: 88.98%
#
# Closed with explanation: 88.07%
#
# Closed with explanation: 66.75%
#
# Closed with explanation: 77.05%
#
# Closed with explanation: 90.54%
#
# Closed with explanation: 90.41%
#
# Closed with explanation: 87.42%
#
# Closed with explanation: 91.84%
#
# Closed with explanation: 78.45%
#
# Closed with explanation: 82.85%
#
# Closed with explanation: 80.03%
#
# Closed with explanation: 74.19%
#
# Closed with explanation: 76.88%
#
# Closed with explanation: 88.77%
#
# Closed with explanation: 74.4%
#
# Closed with explanation: 92.27%
#
# Closed with explanation: 88.23%
#
# Closed with explanation: 87.2%
#
# Closed with explanation: 93.41%
#
# Closed with explanation: 91.51%
#
# Closed with explanation: 77.95%
#
# Closed with explanation: 90.07%
#
# Closed with explanation: 90.39%
#
# Closed with explanation: 81.03%
#
# Closed with explanation: 70.51%
#
# Closed with explanation: 85.02%
#
# Closed with explanation: 79.56%
#
# Closed with explanation: 77.77%
#
# Closed with explanation: 86.76%
#
# Closed with explanation: 81.51%
#
# Closed with explanation: 80.98%
#
# Closed with explanation: 58.59%
#
# Closed with explanation: 86.47%
#
# Closed with explanation: 86.94%
#
# Closed with explanation: 49.84%
#
# Closed with explanation: 91.78%
#
# Closed with explanation: 82.37%
#
# Closed with explanation: 81.25%
#
# Closed with explanation: 86.77%
#
# Closed with explanation: 86.92%
#
# Closed with explanation: 80.31%
#
# Closed with explanation: 92.78%
#
# Closed with explanation: 82.33%
#
# Closed with explanation: 77.28%
#
# Closed with explanation: 58.22%
#
# Closed with explanation: 71.6%
#
# Closed with explanation: 80.0%
#
# Closed with explanation: 82.82%
#
# Closed with explanation: 92.41%
#
# Closed with explanation: 54.11%
#
# Closed with explanation: 77.27%
#
# Closed with explanation: 83.1%
#
# Closed with explanation: 83.79%
#
# Closed with explanation: 70.29%
#
# Closed with explanation: 90.0%
#
# Closed with explanation: 77.19%
#
# Closed with explanation: 75.14%
#
# Closed with explanation: 89.93%
#
# Closed with explanation: 83.63%
#
# Closed with explanation: 82.44%
#
# Closed with explanation: 81.98%
#
# Closed with explanation: 81.96%
#
# Closed with explanation: 82.68%
#
# Closed with explanation: 79.36%
#
# Closed with explanation: 74.31%
#
# Closed with explanation: 88.74%
#
# Closed with explanation: 81.89%
#
# Closed with explanation: 86.96%
#
# Closed with explanation: 82.35%
#
# Closed with explanation: 68.3%
#
# Closed with explanation: 79.84%
#
# Closed with explanation: 84.43%
#
# Closed with explanation: 90.58%
#
# Closed with explanation: 55.89%
#
# Closed with explanation: 76.48%
#
# Closed with explanation: 70.62%
#
# Closed with explanation: 78.55%
#
# Closed with explanation: 85.41%
#
# Closed with explanation: 57.12%
#
# Closed with explanation: 79.13%
#
# Closed with explanation: 82.67%
#
# Closed with explanation: 85.08%
#
# Closed with explanation: 89.14%
#
# Closed with explanation: 80.94%
#
# Closed with explanation: 91.02%
#
# Closed with explanation: 80.16%
#
# Closed with explanation: 77.97%
#
# Closed with explanation: 76.15%
#
# Closed with explanation: 51.53%
#
# Closed with explanation: 73.14%
#
# Closed with explanation: 78.46%
#
# Closed with explanation: 76.86%
#
# Closed with explanation: 85.32%
#
# Closed with explanation: 78.14%
#
# Closed with explanation: 86.09%
#
# Closed with explanation: 89.84%
#
# Closed with explanation: 57.19%
#
# Closed with explanation: 81.22%
#
# Closed with explanation: 85.38%
#
# Closed with explanation: 92.74%
#
# Closed with explanation: 68.8%
#
# Closed with explanation: 73.18%
#
# Closed with explanation: 86.41%
#
# Closed with explanation: 70.01%
#
# Closed with explanation: 82.13%
#
# Closed with explanation: 63.28%
#
# Closed with explanation: 92.4%
#
# Closed with explanation: 83.13%
#
# Closed with explanation: 80.94%
#
# Closed with explanation: 83.66%
#
# Closed with explanation: 75.0%
#
# Closed with explanation: 90.43%
#
# Closed with explanation: 74.72%
#
# Closed with explanation: 88.11%
#
# Closed with explanation: 84.73%
#
# Closed with explanation: 65.61%
#
# Closed with explanation: 77.85%
#
# Closed with explanation: 87.25%
#
# Closed with explanation: 85.48%
#
# Closed with explanation: 78.06%
#
# Closed with explanation: 55.98%
#
# Closed with explanation: 81.97%
#
# Closed with explanation: 82.19%
#
# Closed with explanation: 84.5%
#
# Closed with explanation: 87.06%
#
# Closed with explanation: 78.25%
#
# Closed with explanation: 75.13%
#
# Closed with explanation: 78.9%
#
# Closed with explanation: 91.42%
#
# Closed with explanation: 78.45%
#
# Closed with explanation: 73.72%
#
# Closed with explanation: 87.88%
#
# Closed with explanation: 55.04%
#
# Closed with explanation: 93.03%
#
# Closed with explanation: 77.05%
#
# Closed with explanation: 87.54%
#
# Closed with explanation: 86.68%
#
# Closed with explanation: 83.85%
#
# Closed with explanation: 88.18%
#
# Closed with explanation: 82.47%
#
# Closed with explanation: 88.59%
#
# Closed with explanation: 82.04%
#
# Closed with explanation: 77.37%
#
# Closed with explanation: 82.61%
#
# Closed with explanation: 84.45%
#
# Closed with explanation: 85.12%
#
# Closed with explanation: 87.7%
#
# Closed with explanation: 78.13%
#
# Closed with explanation: 87.02%
#
# Closed with explanation: 84.83%
#
# Closed with explanation: 74.12%
#
# Closed with explanation: 89.46%
#
# Closed with explanation: 88.61%
#
# Closed with explanation: 87.14%
#
# Closed with explanation: 55.7%
#
# Closed with explanation: 73.0%
#
# Closed with explanation: 88.34%
#
# Closed with explanation: 82.76%
#
# Closed with explanation: 86.62%
#
# Closed with explanation: 76.68%
#
# Closed with explanation: 86.75%
#
# Closed with explanation: 91.47%
#
# Closed with explanation: 87.65%
#
# Closed with explanation: 77.58%
#
# Closed with explanation: 73.29%
#
# Closed with explanation: 84.73%
#
# Closed with explanation: 57.13%
#
# Closed with explanation: 76.79%
#
# Closed with explanation: 78.93%
#
# Closed with explanation: 76.64%
#
# Closed with explanation: 78.39%
#
# Closed with explanation: 75.92%
#
# Closed with explanation: 72.3%
#
# Closed with explanation: 63.11%
#
# Closed with explanation: 93.16%
#
# Closed with explanation: 71.38%
#
# Closed with explanation: 76.05%
#
# Closed with explanation: 64.04%
#
# Closed with explanation: 79.59%
#
# Closed with explanation: 79.69%
#
# Closed with explanation: 75.84%
#
# Closed with explanation: 86.05%
#
# Closed with explanation: 79.36%
#
# Closed with explanation: 79.45%
#
# Closed with explanation: 78.81%
#
# Closed with explanation: 72.51%
#
# Closed with explanation: 88.74%
#
# Closed with explanation: 69.51%
#
# Closed with explanation: 73.27%
#
# Closed with explanation: 86.45%
#
# Closed with explanation: 82.73%
#
# Closed with explanation: 94.38%
#
# Closed with explanation: 67.89%
#
# Closed with explanation: 73.72%
#
# Closed with explanation: 86.16%
#
# Closed with explanation: 84.91%
#
# Closed with explanation: 89.64%
#
# Closed with explanation: 68.69%
#
# Closed with explanation: 86.8%
#
# Closed with explanation: 82.5%
#
# Closed with explanation: 92.97%
#
# Closed with explanation: 82.48%
#
# Closed with explanation: 89.53%
#
# Closed with explanation: 92.34%
#
# Closed with explanation: 60.07%
#
# Closed with explanation: 91.04%
#
# Closed with explanation: 80.31%
#
# Closed with explanation: 79.68%
#
# Closed with explanation: 88.61%
#
# Closed with explanation: 79.22%
#
# Closed with explanation: 81.66%
#
# Closed with explanation: 83.6%
#
# Closed with explanation: 87.93%
#
# Closed with explanation: 90.35%
#
# Closed with explanation: 85.2%
#
# Closed with explanation: 62.94%
#
# Closed with explanation: 79.39%
#
# Closed with explanation: 89.6%
#
# Closed with explanation: 88.91%
#
# Closed with explanation: 77.71%
#
# Closed with explanation: 86.5%
#
# Closed with explanation: 81.37%
#
# Closed with explanation: 91.55%
#
# Closed with explanation: 91.58%
#
# Closed with explanation: 79.62%
#
# Closed with explanation: 56.98%
#
# Closed with explanation: 93.74%
#
# Closed with explanation: 86.34%
#
# Closed with explanation: 88.06%
#
# Closed with explanation: 90.66%
#
# Closed with explanation: 87.16%
#
# Closed with explanation: 78.76%
#
# Closed with explanation: 59.66%
#
# Closed with explanation: 56.72%
#
# Closed with explanation: 80.21%
#
# Closed with explanation: 74.97%
#
# Closed with explanation: 64.54%
#
# Closed with explanation: 88.32%
#
# Closed with explanation: 83.82%
#
# Closed with explanation: 89.0%
#
# Closed with explanation: 77.28%
#
# Closed with explanation: 90.44%
#
# Closed with explanation: 83.61%
#
# Closed with explanation: 81.76%
#
# Closed with explanation: 76.7%
#
# Closed with explanation: 80.19%
#
# Closed with explanation: 80.15%
#
# Closed with explanation: 76.62%
#
# Closed with explanation: 81.97%
#
# Closed with explanation: 83.84%
#
# Closed with explanation: 68.7%
#
# Closed with explanation: 93.4%
#
# Closed with explanation: 80.75%
#
# Closed with explanation: 58.39%
#
# Closed with explanation: 84.77%
#
# Closed with explanation: 93.76%
#
# Closed with explanation: 79.44%
#
# Closed with explanation: 66.35%
#
# Closed with explanation: 89.13%
#
# Closed with explanation: 84.54%
#
# Closed with explanation: 80.45%
#
# Closed with explanation: 60.47%
#
# Closed with explanation: 73.83%
#
# Closed with explanation: 82.87%
#
# Closed with explanation: 77.01%
#
# Closed with explanation: 87.25%
#
# Closed with explanation: 57.29%
#
# Closed with explanation: 82.62%
#
# Closed with explanation: 80.6%
#
# Closed with explanation: 76.79%
#
# Closed with explanation: 62.27%
#
# Closed with explanation: 78.66%
#
# Closed with explanation: 88.93%
#
# Closed with explanation: 76.74%
#
# Closed with explanation: 75.16%
#
# Closed with explanation: 83.35%
#
# Closed with explanation: 65.35%
#
# Closed with explanation: 78.67%
#
# Closed with explanation: 88.35%
#
# Closed with explanation: 63.82%
#
# Closed with explanation: 80.23%
#
# Closed with explanation: 88.85%
#
# Closed with explanation: 65.78%
#
# Closed with explanation: 80.63%
#
# Closed with explanation: 85.51%
#
# Closed with explanation: 80.35%
#
# Closed with explanation: 85.74%
#
# Closed with explanation: 83.48%
#
# Closed with explanation: 82.02%
#
# Closed with explanation: 73.74%
#
# Closed with explanation: 83.59%
#
# Closed with explanation: 78.19%
#
# Closed with explanation: 84.31%
#
# Closed with explanation: 83.89%
#
# Closed with explanation: 72.82%
#
# Closed with explanation: 61.82%
#
# Closed with explanation: 55.47%
#
# Closed with explanation: 84.41%
#
# Closed with explanation: 87.85%
#
# Closed with explanation: 83.54%
#
# Closed with explanation: 76.96%
#
# Closed with explanation: 90.71%
#
# Closed with explanation: 84.84%
#
# Closed with explanation: 72.41%
#
# Closed with explanation: 75.73%
#
# Closed with explanation: 74.48%
#
# Closed with explanation: 89.41%
#
# Closed with explanation: 90.19%
#
# Closed with explanation: 76.48%
#
# Closed with explanation: 77.66%
#
# Closed with explanation: 83.01%
#
# Closed with explanation: 61.4%
#
# Closed with explanation: 71.82%
#
# Closed with explanation: 87.47%
#
# Closed with explanation: 69.44%
#
# Closed with explanation: 82.23%
#
# Closed with explanation: 80.42%
#
# Closed with explanation: 80.98%
#
# Closed with explanation: 52.21%
#
# Closed with explanation: 71.92%
#
# Closed with explanation: 74.79%
#
# Closed with explanation: 94.18%
#
# Closed with explanation: 86.58%
#
# Closed with explanation: 88.14%
#
# Closed with explanation: 54.48%
#
# Closed with explanation: 63.54%
#
# Closed with explanation: 77.8%
#
# Closed with explanation: 90.84%
#
# Closed with explanation: 91.53%
#
# Closed with explanation: 90.9%
#
# Closed with explanation: 88.32%
#
# Closed with explanation: 88.59%
#
# Closed with explanation: 82.96%
#
# Closed with explanation: 91.26%
#
# Closed with explanation: 81.65%
#
# Closed with explanation: 78.72%
#
# Closed with explanation: 66.72%
#
# Closed with explanation: 74.15%
#
# Closed with explanation: 74.49%
#
# Closed with explanation: 63.43%
#
# Closed with explanation: 82.53%
#
# Closed with explanation: 80.7%
#
# Closed with explanation: 57.55%
#
# Closed with explanation: 77.19%
#
# Closed with explanation: 93.03%
#
# Closed with explanation: 92.31%
#
# Closed with explanation: 75.91%
#
# Closed with explanation: 79.09%
#
# Closed with explanation: 91.31%
#
# Closed with explanation: 68.62%
#
# Closed with explanation: 84.26%
#
# Closed with explanation: 78.03%
#
# Closed with explanation: 80.63%
#
# Closed with explanation: 83.15%
#
# Closed with explanation: 79.59%
#
# Closed with explanation: 63.24%
#
# Closed with explanation: 75.53%
#
# Closed with explanation: 84.71%
#
# Closed with explanation: 68.88%
#
# Closed with explanation: 90.87%
#
# Closed with explanation: 80.12%
#
# Closed with explanation: 92.92%
#
# Closed with explanation: 62.29%
#
# Closed with explanation: 87.66%
#
# Closed with explanation: 77.74%
#
# Closed with explanation: 78.05%
#
# Closed with explanation: 94.12%
#
# Closed with explanation: 84.81%
#
# Closed with explanation: 84.5%
#
# Closed with explanation: 65.12%
#
# Closed with explanation: 78.34%
#
# Closed with explanation: 82.14%
#
# Closed with explanation: 88.25%
#
# Closed with explanation: 52.39%
#
# Closed with explanation: 80.58%
#
# Closed with explanation: 88.18%
#
# Closed with explanation: 79.9%
#
# Closed with explanation: 74.6%
#
# Closed with explanation: 94.45%
#
# Closed with explanation: 85.55%
#
# Closed with explanation: 67.94%
#
# Closed with explanation: 85.35%
#
# Closed with explanation: 91.71%
#
# Closed with explanation: 67.22%
#
# Closed with explanation: 70.44%
#
# Closed with explanation: 86.26%
#
# Closed with explanation: 87.24%
#
# Closed with explanation: 81.99%
#
# Closed with explanation: 85.74%
#
# Closed with explanation: 79.54%
#
# Closed with explanation: 51.82%
#
# Closed with explanation: 82.21%
#
# Closed with explanation: 81.26%
#
# Closed with explanation: 74.17%
#
# Closed with explanation: 85.71%
#
# Closed with explanation: 75.79%
#
# Closed with explanation: 87.81%
#
# Closed with explanation: 88.08%
#
# Closed with explanation: 74.92%
#
# Closed with explanation: 74.95%
#
# Closed with explanation: 55.42%
#
# Closed with explanation: 67.03%
#
# Closed with explanation: 82.35%
#
# Closed with explanation: 83.92%
#
# Closed with explanation: 86.28%
#
# Closed with explanation: 83.31%
#
# Closed with explanation: 91.93%
#
# Closed with explanation: 78.87%
#
# Closed with explanation: 88.5%
#
# Closed with explanation: 83.09%
#
# Closed with explanation: 88.44%
#
# Closed with explanation: 88.52%
#
# Closed with explanation: 92.53%
#
# Closed with explanation: 91.94%
#
# Closed with explanation: 77.2%
#
# Closed with explanation: 87.62%
#
# Closed with explanation: 68.87%
#
# Closed with explanation: 83.14%
#
# Closed with explanation: 64.57%
#
# Closed with explanation: 93.24%
#
# Closed with explanation: 83.0%
#
# Closed with explanation: 89.78%
#
# Closed with explanation: 75.38%
#
# Closed with explanation: 88.27%
#
# Closed with explanation: 85.09%
#
# Closed with explanation: 72.6%
#
# Closed with explanation: 77.66%
#
# Closed with explanation: 70.1%
#
# Closed with explanation: 79.34%
#
# Closed with explanation: 92.38%
#
# Closed with explanation: 85.49%
#
# Closed with explanation: 90.16%
#
# Closed with explanation: 82.58%
#
# Closed with explanation: 85.59%
#
# Closed with explanation: 90.47%
#
# Closed with explanation: 76.53%
#
# Closed with explanation: 81.6%
#
# Closed with explanation: 80.68%
#
# Closed with explanation: 62.65%
#
# Closed with explanation: 90.91%
#
# Closed with explanation: 90.13%
#
# Closed with explanation: 81.82%
#
# Closed with explanation: 92.33%
#
# Closed with explanation: 64.45%
#
# Closed with explanation: 79.97%
#
# Closed with explanation: 82.42%
#
# Closed with explanation: 69.35%
#
# Closed with explanation: 86.63%
#
# Closed with explanation: 72.05%
#
# Closed with explanation: 56.47%
#
# Closed with explanation: 83.58%
#
# Closed with explanation: 82.87%
#
# Closed with explanation: 72.47%
#
# Closed with explanation: 84.75%
#
# Closed with explanation: 67.67%
#
# Closed with explanation: 85.11%
#
# Closed with explanation: 86.41%
#
# Closed with explanation: 73.89%
#
# Closed with explanation: 78.15%
#
# Closed with explanation: 83.47%
#
# Closed with explanation: 80.88%
#
# Closed with explanation: 63.92%
#
# Closed with explanation: 80.01%
#
# Closed with explanation: 77.79%
#
# Closed with explanation: 78.16%
#
# Closed with explanation: 79.06%
#
# Closed with explanation: 80.21%
#
# Closed with explanation: 83.9%
#
# Closed with explanation: 76.71%
#
# Closed with explanation: 93.0%
#
# Closed with explanation: 51.9%
#
# Closed with explanation: 79.9%
#
# Closed with explanation: 80.95%
#
# Closed with explanation: 76.28%
#
# Closed with explanation: 86.83%
#
# Closed with explanation: 86.59%
#
# Closed with explanation: 79.29%
#
# Closed with explanation: 79.5%
#
# Closed with explanation: 91.69%
#
# Closed with explanation: 84.13%
#
# Closed with explanation: 52.48%
#
# Closed with explanation: 77.0%
#
# Closed with explanation: 82.29%
#
# Closed with explanation: 87.65%
#
# Closed with explanation: 62.33%
#
# Closed with explanation: 54.57%
#
# Closed with explanation: 80.56%
#
# Closed with explanation: 84.21%
#
# Closed with explanation: 86.62%
#
# Closed with explanation: 69.18%
#
# Closed with explanation: 58.79%
#
# Closed with explanation: 72.47%
#
# Closed with explanation: 83.79%
#
# Closed with explanation: 79.44%
#
# Closed with explanation: 81.54%
#
# Closed with explanation: 58.26%
#
# Closed with explanation: 89.06%
#
# Closed with explanation: 92.67%
#
# Closed with explanation: 82.06%
#
# Closed with explanation: 90.71%
#
# Closed with explanation: 81.82%
#
# Closed with explanation: 58.97%
#
# Closed with explanation: 78.1%
#
# Closed with explanation: 78.09%
#
# Closed with explanation: 76.99%
#
# Closed with explanation: 82.31%
#
# Closed with explanation: 52.23%
#
# Closed with explanation: 77.16%
#
# Closed with explanation: 88.33%
#
# Closed with explanation: 72.96%
#
# Closed with explanation: 75.25%
#
# Closed with explanation: 80.02%
#
# Closed with explanation: 79.47%
#
# Closed with explanation: 85.86%
#
# Closed with explanation: 53.27%
#
# Closed with explanation: 58.06%
#
# Closed with explanation: 85.51%
#
# Closed with explanation: 68.58%
#
# Closed with explanation: 79.2%
#
# Closed with explanation: 77.97%
#
# Closed with explanation: 78.07%
#
# Closed with explanation: 66.06%
#
# Closed with explanation: 82.32%
#
# Closed with explanation: 81.15%
#
# Closed with explanation: 91.0%
#
# Closed with explanation: 79.79%
#
# Closed with explanation: 77.99%
#
# Closed with explanation: 77.02%
#
# Closed with explanation: 86.53%
#
# Closed with explanation: 86.5%
#
# Closed with explanation: 92.77%
#
# Closed with explanation: 83.29%
#
# Closed with explanation: 75.66%
#
# Closed with explanation: 91.32%
#
# Closed with explanation: 85.23%
#
# Closed with explanation: 90.74%
#
# Closed with explanation: 76.45%
#
# Closed with explanation: 84.87%
#
# Closed with explanation: 75.62%
#
# Closed with explanation: 75.06%
#
# Closed with explanation: 67.56%
#
# Closed with explanation: 91.99%
#
# Closed with explanation: 92.88%
#
# Closed with explanation: 78.7%
#
# Closed with explanation: 77.06%
#
# Closed with explanation: 87.6%
#
# Closed with explanation: 61.07%
#
# Closed with explanation: 77.4%
#
# Closed with explanation: 85.99%
#
# Closed with explanation: 79.49%
#
# Closed with explanation: 66.92%
#
# Closed with explanation: 59.7%
#
# Closed with explanation: 75.93%
#
# Closed with explanation: 63.92%
#
# Closed with explanation: 67.46%
#
# Closed with explanation: 75.05%
#
# Closed with explanation: 79.73%
#
# Closed with explanation: 70.77%
#
# Closed with explanation: 81.02%
#
# Closed with explanation: 75.89%
#
# Closed with explanation: 88.32%
#
# Closed with explanation: 84.99%
#
# Closed with explanation: 80.07%
#
# Closed with explanation: 59.25%
#
# Closed with explanation: 83.15%
#
# Closed with explanation: 55.11%
#
# ...
#
# Closed with explanation: 85.31%
#
# Closed with explanation: 82.7%
#
# Closed with explanation: 84.73%
#
# Closed with explanation: 89.23%
#
# Closed with explanation: 71.01%
#
# Closed with explanation: 81.99%
#
# Closed with explanation: 89.45%
#
# Closed with explanation: 72.15%
#
# Closed with explanation: 87.86%
#
# Closed with explanation: 64.17%
#
# Closed with explanation: 82.7%
#
# Closed with explanation: 82.05%
#
# Closed with explanation: 86.13%
#
# Closed with explanation: 90.61%
#
# Closed with explanation: 84.01%
#
# Closed with explanation: 75.48%
#
# Closed with explanation: 92.66%
#
# Closed with explanation: 54.56%
#
# Closed with explanation: 48.43%
#
# Closed with explanation: 83.76%
#
# Closed with explanation: 80.18%
#
# Closed with explanation: 91.62%
#
# Closed with explanation: 79.77%
#
# Closed with explanation: 72.85%
#
# Closed with explanation: 81.6%
#
# Closed with explanation: 89.65%
#
# Closed with explanation: 84.64%
#
# Closed with explanation: 80.3%
#
# Closed with explanation: 94.85%
#
# Closed with explanation: 87.13%
#
# Closed with explanation: 76.13%
#
# Closed with explanation: 63.66%
#
# Closed with explanation: 74.79%
#
# Closed with explanation: 86.85%
#
# Closed with explanation: 85.59%
#
# Closed with explanation: 84.42%
#
# Closed with explanation: 88.95%
#
# Closed with explanation: 73.84%
#
# Closed with explanation: 75.65%
#
# Closed with explanation: 62.21%
#
# Closed with explanation: 89.59%
#
# Closed with explanation: 87.33%
#
# Closed with explanation: 87.39%
#
# Closed with explanation: 88.41%
#
# Closed with explanation: 88.15%
#
# Closed with explanation: 66.67%
#
# Closed with explanation: 76.57%
#
# Closed with explanation: 68.74%
#
# Closed with explanation: 78.49%
#
# Closed with explanation: 53.29%
#
# Closed with explanation: 87.01%
#
# Closed with explanation: 91.74%
#
# Closed with explanation: 86.17%
#
# Closed with explanation: 78.23%
#
# Closed with explanation: 82.98%
#
# Closed with explanation: 89.21%
#
# Closed with explanation: 79.06%
#
# Closed with explanation: 76.39%
#
# Closed with explanation: 82.68%
#
# Closed with explanation: 88.73%
#
# Closed with explanation: 87.07%
#
# Closed with explanation: 84.94%
#
# Closed with explanation: 88.31%
#
# Closed with explanation: 85.88%
#
# Closed with explanation: 76.63%
#
# Closed with explanation: 78.84%
#
# Closed with explanation: 91.75%
#
# Closed with explanation: 76.78%
#
# Closed with explanation: 61.18%
#
# Closed with explanation: 93.77%
#
# Closed with explanation: 86.96%
#
# Closed with explanation: 87.15%
#
# Closed with explanation: 79.94%
#
# Closed with explanation: 80.03%
#
# Closed with explanation: 74.28%
#
# Closed with explanation: 74.47%
#
# Closed with explanation: 88.68%
#
# Closed with explanation: 84.02%
#
# Closed with explanation: 82.26%
#
# Closed with explanation: 82.89%
#
# Closed with explanation: 54.39%
#
# Closed with explanation: 84.63%
#
# Closed with explanation: 87.42%
#
# Closed with explanation: 75.07%
#
# Closed with explanation: 76.19%
#
# Closed with explanation: 94.54%
#
# Closed with explanation: 87.29%
#
# Closed with explanation: 78.99%
#
# Closed with explanation: 74.12%
#
# Closed with explanation: 73.38%
#
# Closed with explanation: 70.59%
#
# Closed with explanation: 87.55%
#
# Closed with explanation: 70.37%
#
# Closed with explanation: 84.08%
#
# Closed with explanation: 80.25%
#
# Closed with explanation: 90.4%
#
# Closed with explanation: 71.81%
#
# Closed with explanation: 82.62%
#
# Closed with explanation: 57.16%
#
# Closed with explanation: 74.6%
#
# Closed with explanation: 91.31%
#
# Closed with explanation: 90.96%
#
# Closed with explanation: 79.21%
#
# Closed with explanation: 83.53%
#
# Closed with explanation: 94.45%
#
# Closed with explanation: 78.53%
#
# Closed with explanation: 88.92%
#
# Closed with explanation: 86.65%
#
# Closed with explanation: 77.8%
#
# Closed with explanation: 81.19%
#
# Closed with explanation: 87.95%
#
# Closed with explanation: 89.64%
#
# Closed with explanation: 77.66%
#
# Closed with explanation: 91.76%
#
# Closed with explanation: 80.2%
#
# Closed with explanation: 85.38%
#
# Closed with explanation: 89.04%
#
# Closed with explanation: 78.07%
#
# Closed with explanation: 90.93%
#
# Closed with explanation: 91.05%
#
# Closed with explanation: 75.62%
#
# Closed with explanation: 78.57%
#
# Closed with explanation: 90.16%
#
# Closed with explanation: 87.79%
#
# Closed with explanation: 71.97%
#
# Closed with explanation: 87.55%
#
# Closed with explanation: 92.3%
#
# Closed with explanation: 55.88%
#
# Closed with explanation: 81.48%
#
# Closed with explanation: 76.24%
#
# Closed with explanation: 89.76%
#
# Closed with explanation: 82.27%
#
# Closed with explanation: 77.76%
#
# Closed with explanation: 83.4%
#
# Closed with explanation: 83.02%
#
# Closed with explanation: 80.45%
#
# Closed with explanation: 83.81%
#
# Closed with explanation: 89.34%
#
# Closed with explanation: 90.76%
#
# Closed with explanation: 76.05%
#
# Closed with explanation: 79.84%
#
# Closed with explanation: 84.73%
#
# Closed with explanation: 74.42%
#
# Closed with explanation: 90.19%
#
# Closed with explanation: 76.32%
#
# Closed with explanation: 77.51%
#
# Closed with explanation: 79.52%
#
# Closed with explanation: 85.44%
#
# Closed with explanation: 83.12%
#
# Closed with explanation: 89.83%
#
# Closed with explanation: 78.29%
#
# Closed with explanation: 58.79%
#
# Closed with explanation: 93.04%
#
# Closed with explanation: 87.56%
#
# Closed with explanation: 90.12%
#
# Closed with explanation: 85.25%
#
# Closed with explanation: 77.95%
#
# Closed with explanation: 92.8%
#
# Closed with explanation: 78.0%
#
# Closed with explanation: 82.55%
#
# Closed with explanation: 84.39%
#
# Closed with explanation: 68.43%
#
# Closed with explanation: 84.42%
#
# Closed with explanation: 87.2%
#
# Closed with explanation: 81.57%
#
# Closed with explanation: 76.0%
#
# Closed with explanation: 87.02%
#
# Closed with explanation: 77.98%
#
# Closed with explanation: 85.51%
#
# Closed with explanation: 80.0%
#
# Closed with explanation: 90.51%
#
# Closed with explanation: 77.47%
#
# Closed with explanation: 77.48%
#
# Closed with explanation: 84.88%
#
# Closed with explanation: 75.46%
#
# Closed with explanation: 77.17%
#
# Closed with explanation: 85.9%
#
# Closed with explanation: 81.63%
#
# Closed with explanation: 66.65%
#
# Closed with explanation: 88.64%
#
# Closed with explanation: 87.69%
#
# Closed with explanation: 80.96%
#
# Closed with explanation: 84.15%
#
# Closed with explanation: 88.85%
#
# Closed with explanation: 66.01%
#
# Closed with explanation: 86.15%
#
# Closed with explanation: 72.11%
#
# Closed with explanation: 89.68%
#
# Closed with explanation: 85.76%
#
# Closed with explanation: 62.92%
#
# Closed with explanation: 92.2%
#
# Closed with explanation: 89.98%
#
# Closed with explanation: 83.79%
#
# Closed with explanation: 84.41%
#
# Closed with explanation: 67.16%
#
# Closed with explanation: 88.3%
#
# Closed with explanation: 86.02%
#
# Closed with explanation: 84.15%
#
# Closed with explanation: 86.2%
#
# Closed with explanation: 67.32%
#
# Closed with explanation: 81.87%
#
# Closed with explanation: 82.46%
#
# Closed with explanation: 90.08%
#
# Closed with explanation: 58.26%
#
# Closed with explanation: 74.17%
#
# Closed with explanation: 78.54%
#
# Closed with explanation: 89.57%
#
# Closed with explanation: 82.68%
#
# Closed with explanation: 78.57%
#
# Closed with explanation: 78.34%
#
# Closed with explanation: 89.45%
#
# Closed with explanation: 79.06%
#
# Closed with explanation: 83.53%
#
# Closed with explanation: 89.11%
#
# Closed with explanation: 74.43%
#
# Closed with explanation: 85.09%
#
# Closed with explanation: 93.58%
#
# Closed with explanation: 69.15%
#
# Closed with explanation: 72.84%
#
# Closed with explanation: 83.67%
#
# Closed with explanation: 86.69%
#
# Closed with explanation: 83.22%
#
# Closed with explanation: 79.5%
#
# Closed with explanation: 85.44%
#
# Closed with explanation: 90.75%
#
# Closed with explanation: 76.8%
#
# Closed with explanation: 88.94%
#
# Closed with explanation: 75.05%
#
# Closed with explanation: 70.05%
#
# Closed with explanation: 90.45%
#
# Closed with explanation: 77.3%
#
# Closed with explanation: 85.16%
#
# Closed with explanation: 91.48%
#
# Closed with explanation: 70.69%
#
# Closed with explanation: 89.15%
#
# Closed with explanation: 79.67%
#
# Closed with explanation: 73.29%
#
# Closed with explanation: 80.01%
#
# Closed with explanation: 83.92%
#
# Closed with explanation: 81.72%
#
# Closed with explanation: 56.73%
#
# Closed with explanation: 88.02%
#
# Closed with explanation: 56.74%
#
# Closed with explanation: 84.93%
#
# Closed with explanation: 84.69%
#
# Closed with explanation: 81.26%
#
# Closed with explanation: 79.43%
#
# Closed with explanation: 88.13%
#
# Closed with explanation: 50.63%
#
# Closed with explanation: 57.72%
#
# Closed with explanation: 77.24%
#
# Closed with explanation: 81.42%
#
# Closed with explanation: 61.58%
#
# Closed with explanation: 75.15%
#
# Closed with explanation: 75.84%
#
# Closed with explanation: 80.42%
#
# Closed with explanation: 74.23%
#
# Closed with explanation: 69.35%
#
# Closed with explanation: 92.3%
#
# Closed with explanation: 78.04%
#
# Closed with explanation: 78.86%
#
# Closed with explanation: 83.71%
#
# Closed with explanation: 89.99%
#
# Closed with explanation: 71.93%
#
# Closed with explanation: 68.65%
#
# Closed with explanation: 82.73%
#
# Closed with explanation: 75.73%
#
# Closed with explanation: 71.79%
#
# Closed with explanation: 83.69%
#
# Closed with explanation: 63.2%
#
# Closed with explanation: 76.7%
#
# Closed with explanation: 55.68%
#
# Closed with explanation: 91.31%
#
# Closed with explanation: 82.91%
#
# Closed with explanation: 89.46%
#
# Closed with explanation: 91.32%
#
# Closed with explanation: 87.65%
#
# Closed with explanation: 86.48%
#
# Closed with explanation: 92.75%
#
# Closed with explanation: 74.16%
#
# Closed with explanation: 74.46%
#
# Closed with explanation: 92.38%
#
# Closed with explanation: 74.17%
#
# Closed with explanation: 90.75%
#
# Closed with explanation: 84.07%
#
# Closed with explanation: 78.53%
#
# Closed with explanation: 66.3%
#
# Closed with explanation: 74.54%
#
# Closed with explanation: 79.3%
#
# Closed with explanation: 78.58%
#
# Closed with explanation: 75.01%
#
# Closed with explanation: 73.84%
#
# Closed with explanation: 87.05%
#
# Closed with explanation: 72.27%
#
# Closed with explanation: 89.12%
#
# Closed with explanation: 84.98%
#
# Closed with explanation: 61.19%
#
# Closed with explanation: 73.85%
#
# Closed with explanation: 85.61%
#
# Closed with explanation: 87.47%
#
# Closed with explanation: 77.07%
#
# Closed with explanation: 90.48%
#
# Closed with explanation: 86.11%
#
# Closed with explanation: 91.97%
#
# Closed with explanation: 82.07%
#
# Closed with explanation: 64.29%
#
# Closed with explanation: 76.21%
#
# Closed with explanation: 86.36%
#
# Closed with explanation: 88.93%
#
# Closed with explanation: 73.34%
#
# Closed with explanation: 76.21%
#
# Closed with explanation: 75.14%
#
# Closed with explanation: 94.24%
#
# Closed with explanation: 89.92%
#
# Closed with explanation: 73.91%
#
# Closed with explanation: 81.9%
#
# Closed with explanation: 57.73%
#
# Closed with explanation: 85.75%
#
# Closed with explanation: 88.83%
#
# Closed with explanation: 83.84%
#
# Closed with explanation: 76.05%
#
# Closed with explanation: 77.67%
#
# Closed with explanation: 90.82%
#
# Closed with explanation: 81.69%
#
# Closed with explanation: 76.41%
#
# Closed with explanation: 90.47%
#
# Closed with explanation: 67.99%
#
# Closed with explanation: 88.65%
#
# Closed with explanation: 74.24%
#
# Closed with explanation: 75.31%
#
# Closed with explanation: 84.95%
#
# Closed with explanation: 81.41%
#
# Closed with explanation: 89.41%
#
# Closed with explanation: 89.91%
#
# Closed with explanation: 77.63%
#
# Closed with explanation: 75.79%
#
# Closed with explanation: 81.1%
#
# Closed with explanation: 85.78%
#
# Closed with explanation: 82.05%
#
# Closed with explanation: 85.82%
#
# Closed with explanation: 71.91%
#
# Closed with explanation: 71.44%
#
# Closed with explanation: 74.99%
#
# Closed with explanation: 84.65%
#
# Closed with explanation: 70.34%
#
# Closed with explanation: 76.28%
#
# Closed with explanation: 56.06%
#
# Closed with explanation: 92.61%
#
# Closed with explanation: 85.38%
#
# Closed with explanation: 55.32%
#
# Closed with explanation: 75.02%
#
# Closed with explanation: 79.35%
#
# Closed with explanation: 74.05%
#
# Closed with explanation: 86.44%
#
# Closed with explanation: 81.13%
#
# Closed with explanation: 90.4%
#
# Closed with explanation: 60.27%
#
# Closed with explanation: 76.84%
#
# Closed with explanation: 86.62%
#
# Closed with explanation: 91.19%
#
# Closed with explanation: 78.93%
#
# Closed with explanation: 86.22%
#
# Closed with explanation: 89.31%
#
# Closed with explanation: 81.35%
#
# Closed with explanation: 80.33%
#
# Closed with explanation: 79.71%
#
# Closed with explanation: 80.49%
#
# Closed with explanation: 93.61%
#
# Closed with explanation: 86.71%
#
# Closed with explanation: 84.71%
#
# Closed with explanation: 81.25%
#
# Closed with explanation: 80.92%
#
# Closed with explanation: 82.82%
#
# Closed with explanation: 82.69%
#
# Closed with explanation: 90.52%
#
# Closed with explanation: 83.07%
#
# Closed with explanation: 82.6%
#
# Closed with explanation: 72.92%
#
# Closed with explanation: 79.98%
#
# Closed with explanation: 84.35%
#
# Closed with explanation: 78.63%
#
# Closed with explanation: 84.24%
#
# Closed with explanation: 56.07%
#
# Closed with explanation: 90.73%
#
# Closed with explanation: 74.8%
#
# Closed with explanation: 83.98%
#
# Closed with explanation: 85.56%
#
# Closed with explanation: 79.17%
#
# Closed with explanation: 55.65%
#
# Closed with explanation: 85.04%
#
# Closed with explanation: 58.53%
#
# Closed with explanation: 93.96%
#
# Closed with explanation: 75.84%
#
# Closed with explanation: 82.91%
#
# Closed with explanation: 80.46%
#
# Closed with explanation: 90.2%
#
# Closed with explanation: 65.08%
#
# Closed with explanation: 84.5%
#
# Closed with explanation: 62.55%
#
# Closed with explanation: 78.08%
#
# Closed with explanation: 80.83%
#
# Closed with explanation: 85.62%
#
# Closed with explanation: 78.64%
#
# Closed with explanation: 84.93%
#
# Closed with explanation: 88.96%
#
# Closed with explanation: 87.21%
#
# Closed with explanation: 86.23%
#
# Closed with explanation: 74.51%
#
# Closed with explanation: 91.48%
#
# Closed with explanation: 78.82%
#
# Closed with explanation: 93.83%
#
# Closed with explanation: 63.58%
#
# Closed with explanation: 75.92%
#
# Closed with explanation: 84.53%
#
# Closed with explanation: 78.8%
#
# Closed with explanation: 80.37%
#
# Closed with explanation: 65.15%
#
# Closed with explanation: 72.54%
#
# Closed with explanation: 86.1%
#
# Closed with explanation: 78.75%
#
# Closed with explanation: 78.24%
#
# Closed with explanation: 89.39%
#
# Closed with explanation: 61.39%
#
# Closed with explanation: 91.27%
#
# Closed with explanation: 75.85%
#
# Closed with explanation: 73.8%
#
# Closed with explanation: 69.46%
#
# Closed with explanation: 75.51%
#
# Closed with explanation: 84.97%
#
# Closed with explanation: 80.09%
#
# Closed with explanation: 87.99%
#
# Closed with explanation: 82.19%
#
# Closed with explanation: 80.42%
#
# Closed with explanation: 83.24%
#
# Closed with explanation: 81.03%
#
# Closed with explanation: 77.63%
#
# Closed with explanation: 82.57%
#
# Closed with explanation: 72.65%
#
# Closed with explanation: 93.39%
#
# Closed with explanation: 89.64%
#
# Closed with explanation: 91.87%
#
# Closed with explanation: 68.65%
#
# Closed with explanation: 67.82%
#
# Closed with explanation: 86.5%
#
# Closed with explanation: 79.79%
#
# Closed with explanation: 85.41%
#
# Closed with explanation: 78.28%
#
# Closed with explanation: 88.53%
#
# Closed with explanation: 91.14%
#
# Closed with explanation: 90.96%
#
# Closed with explanation: 65.67%
#
# Closed with explanation: 84.91%
#
# Closed with explanation: 76.51%
#
# Closed with explanation: 77.98%
#
# Closed with explanation: 71.29%
#
# Closed with explanation: 77.86%
#
# Closed with explanation: 78.34%
#
# Closed with explanation: 86.37%
#
# Closed with explanation: 71.11%
#
# Closed with explanation: 68.46%
#
# Closed with explanation: 74.18%
#
# Closed with explanation: 74.96%
#
# Closed with explanation: 80.29%
#
# Closed with explanation: 79.55%
#
# Closed with explanation: 61.66%
#
# Closed with explanation: 79.81%
#
# Closed with explanation: 72.92%
#
# Closed with explanation: 86.56%
#
# Closed with explanation: 66.02%
#
# Closed with explanation: 89.18%
#
# Closed with explanation: 83.63%
#
# Closed with explanation: 79.93%
#
# Closed with explanation: 91.87%
#
# Closed with explanation: 87.97%
#
# Closed with explanation: 87.42%
#
# Closed with explanation: 78.68%
#
# Closed with explanation: 82.13%
#
# Closed with explanation: 77.68%
#
# Closed with explanation: 67.86%
#
# Closed with explanation: 90.68%
#
# Closed with explanation: 71.53%
#
# Closed with explanation: 72.76%
#
# Closed with explanation: 80.52%
#
# Closed with explanation: 80.31%
#
# Closed with explanation: 79.34%
#
# Closed with explanation: 82.98%

# %%
test_data_prod
# Out:
# 'Closed with explanation'
